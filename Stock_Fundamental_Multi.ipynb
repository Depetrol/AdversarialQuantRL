# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/Stock_Fundamental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## install finrl library
#!pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import pandas as pd
print(pd.__version__)
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
import os
from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from finrl.main import check_and_make_directories
from pprint import pprint
from stable_baselines3.common.logger import configure
import sys
sys.path.append("../FinRL")

import itertools

from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

from finrl.config_tickers import DOW_30_TICKER
# Out:
# 1.3.5
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2019-01-01'
TEST_START_DATE = '2019-01-01'
TEST_END_DATE = '2021-01-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (88061, 8)

# %%
df.shape
# Out:
# (88061, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.747390  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  42.737896    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.193850   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941101    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  31.093391    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
df['date'] = pd.to_datetime(df['date'],format='%Y-%m-%d')

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#         date       open       high        low      close     volume   tic  day
# 0 2009-01-02   3.067143   3.251429   3.041429   2.747390  746015200  AAPL    4
# 1 2009-01-02  58.590000  59.080002  57.750000  42.737896    6547900  AMGN    4
# 2 2009-01-02  18.570000  19.520000  18.400000  15.193850   10955700   AXP    4
# 3 2009-01-02  42.799999  45.560001  42.779999  33.941101    7010200    BA    4
# 4 2009-01-02  44.910000  46.980000  44.709999  31.093391    7117200   CAT    4

# %%
# Import fundamental data from my GitHub repository
url = 'https://raw.githubusercontent.com/mariko-sawada/FinRL_with_fundamental_data/main/dow_30_fundamental_wrds.csv'

fund = pd.read_csv(url)
# Out:
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3550: DtypeWarning: Columns (16,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Check the imported dataset
fund.head()
# Out:
#    gvkey  datadate  fyearq  fqtr  fyr indfmt consol popsrc datafmt  tic  ...  \
# 0   1447  19990630    1999     2   12   INDL      C      D     STD  AXP  ...
# 1   1447  19990930    1999     3   12   INDL      C      D     STD  AXP  ...
# 2   1447  19991231    1999     4   12   INDL      C      D     STD  AXP  ...
# 3   1447  20000331    2000     1   12   INDL      C      D     STD  AXP  ...
# 4   1447  20000630    2000     2   12   INDL      C      D     STD  AXP  ...
#
#   dvpsxq mkvaltq     prccq     prchq     prclq  adjex ggroup    gind gsector  \
# 0  0.225     NaN  130.1250  142.6250  114.5000    3.0   4020  402020      40
# 1  0.000     NaN  135.0000  150.6250  121.8750    3.0   4020  402020      40
# 2  0.225     NaN  166.2500  168.8750  130.2500    3.0   4020  402020      40
# 3  0.225     NaN  148.9375  169.5000  119.5000    3.0   4020  402020      40
# 4  0.080     NaN   52.1250   57.1875   43.9375    1.0   4020  402020      40
#
#     gsubind
# 0  40202010
# 1  40202010
# 2  40202010
# 3  40202010
# 4  40202010
#
# [5 rows x 647 columns]

# %%
# List items that are used to calculate financial ratios

items = [
    'datadate', # Date
    'tic', # Ticker
    'oiadpq', # Quarterly operating income
    'revtq', # Quartely revenue
    'niq', # Quartely net income
    'atq', # Total asset
    'teqq', # Shareholder's equity
    'epspiy', # EPS(Basic) incl. Extraordinary items
    'ceqq', # Common Equity
    'cshoq', # Common Shares Outstanding
    'dvpspq', # Dividends per share
    'actq', # Current assets
    'lctq', # Current liabilities
    'cheq', # Cash & Equivalent
    'rectq', # Recievalbles
    'cogsq', # Cost of  Goods Sold
    'invtq', # Inventories
    'apq',# Account payable
    'dlttq', # Long term debt
    'dlcq', # Debt in current liabilites
    'ltq' # Liabilities   
]

# Omit items that will not be used
fund_data = fund[items]

# %%
# Rename column names for the sake of readability
fund_data = fund_data.rename(columns={
    'datadate':'date', # Date
    'oiadpq':'op_inc_q', # Quarterly operating income
    'revtq':'rev_q', # Quartely revenue
    'niq':'net_inc_q', # Quartely net income
    'atq':'tot_assets', # Assets
    'teqq':'sh_equity', # Shareholder's equity
    'epspiy':'eps_incl_ex', # EPS(Basic) incl. Extraordinary items
    'ceqq':'com_eq', # Common Equity
    'cshoq':'sh_outstanding', # Common Shares Outstanding
    'dvpspq':'div_per_sh', # Dividends per share
    'actq':'cur_assets', # Current assets
    'lctq':'cur_liabilities', # Current liabilities
    'cheq':'cash_eq', # Cash & Equivalent
    'rectq':'receivables', # Receivalbles
    'cogsq':'cogs_q', # Cost of  Goods Sold
    'invtq':'inventories', # Inventories
    'apq': 'payables',# Account payable
    'dlttq':'long_debt', # Long term debt
    'dlcq':'short_debt', # Debt in current liabilites
    'ltq':'tot_liabilities' # Liabilities   
})

# %%
# Check the data
fund_data.head()
# Out:
#        date  tic  op_inc_q   rev_q  net_inc_q  tot_assets  sh_equity  \
# 0  19990630  AXP     896.0  5564.0      646.0    132452.0     9762.0
# 1  19990930  AXP     906.0  5584.0      648.0    132616.0     9744.0
# 2  19991231  AXP     845.0  6009.0      606.0    148517.0    10095.0
# 3  20000331  AXP     920.0  6021.0      656.0    150662.0    10253.0
# 4  20000630  AXP    1046.0  6370.0      740.0    148553.0    10509.0
#
#    eps_incl_ex   com_eq  sh_outstanding  ...  cur_assets  cur_liabilities  \
# 0         2.73   9762.0           449.0  ...         NaN              NaN
# 1         4.18   9744.0           447.6  ...         NaN              NaN
# 2         5.54  10095.0           446.9  ...         NaN              NaN
# 3         1.48  10253.0           444.7  ...         NaN              NaN
# 4         1.05  10509.0          1333.0  ...         NaN              NaN
#
#    cash_eq  receivables  cogs_q  inventories  payables  long_debt  short_debt  \
# 0   6096.0      46774.0  4668.0        448.0   22282.0     7005.0     24785.0
# 1   5102.0      48827.0  4678.0        284.0   23587.0     6720.0     24683.0
# 2  10391.0      54033.0  5164.0        277.0   25719.0     4685.0     32437.0
# 3   7425.0      53663.0  5101.0        315.0   26379.0     5670.0     29342.0
# 4   6841.0      54286.0  5324.0        261.0   29536.0     5336.0     26170.0
#
#    tot_liabilities
# 0         122690.0
# 1         122872.0
# 2         138422.0
# 3         140409.0
# 4         138044.0
#
# [5 rows x 21 columns]

# %%
# Calculate financial ratios
date = pd.to_datetime(fund_data['date'],format='%Y%m%d')

tic = fund_data['tic'].to_frame('tic')

# Profitability ratios
# Operating Margin
OPM = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='OPM')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        OPM[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        OPM.iloc[i] = np.nan
    else:
        OPM.iloc[i] = np.sum(fund_data['op_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])

# Net Profit Margin        
NPM = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='NPM')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        NPM[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        NPM.iloc[i] = np.nan
    else:
        NPM.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])

# Return On Assets
ROA = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='ROA')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        ROA[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        ROA.iloc[i] = np.nan
    else:
        ROA.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/fund_data['tot_assets'].iloc[i]

# Return on Equity
ROE = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='ROE')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        ROE[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        ROE.iloc[i] = np.nan
    else:
        ROE.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/fund_data['sh_equity'].iloc[i]        

# For calculating valuation ratios in the next subpart, calculate per share items in advance
# Earnings Per Share       
EPS = fund_data['eps_incl_ex'].to_frame('EPS')

# Book Per Share
BPS = (fund_data['com_eq']/fund_data['sh_outstanding']).to_frame('BPS') # Need to check units

#Dividend Per Share
DPS = fund_data['div_per_sh'].to_frame('DPS')

# Liquidity ratios
# Current ratio
cur_ratio = (fund_data['cur_assets']/fund_data['cur_liabilities']).to_frame('cur_ratio')

# Quick ratio
quick_ratio = ((fund_data['cash_eq'] + fund_data['receivables'] )/fund_data['cur_liabilities']).to_frame('quick_ratio')

# Cash ratio
cash_ratio = (fund_data['cash_eq']/fund_data['cur_liabilities']).to_frame('cash_ratio')


# Efficiency ratios
# Inventory turnover ratio
inv_turnover = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='inv_turnover')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        inv_turnover[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        inv_turnover.iloc[i] = np.nan
    else:
        inv_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['inventories'].iloc[i]

# Receivables turnover ratio       
acc_rec_turnover = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='acc_rec_turnover')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        acc_rec_turnover[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        acc_rec_turnover.iloc[i] = np.nan
    else:
        acc_rec_turnover.iloc[i] = np.sum(fund_data['rev_q'].iloc[i-3:i])/fund_data['receivables'].iloc[i]

# Payable turnover ratio
acc_pay_turnover = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='acc_pay_turnover')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        acc_pay_turnover[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        acc_pay_turnover.iloc[i] = np.nan
    else:
        acc_pay_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['payables'].iloc[i]
        
## Leverage financial ratios
# Debt ratio
debt_ratio = (fund_data['tot_liabilities']/fund_data['tot_assets']).to_frame('debt_ratio')

# Debt to Equity ratio
debt_to_equity = (fund_data['tot_liabilities']/fund_data['sh_equity']).to_frame('debt_to_equity')
# Out:
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_95077/22741674.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   OPM.iloc[i] = np.sum(fund_data['op_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_95077/22741674.py:15: RuntimeWarning: invalid value encountered in scalar divide
#   OPM.iloc[i] = np.sum(fund_data['op_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_95077/22741674.py:25: RuntimeWarning: divide by zero encountered in scalar divide
#   NPM.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_95077/22741674.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   NPM.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_95077/22741674.py:77: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['inventories'].iloc[i]
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_95077/22741674.py:77: RuntimeWarning: invalid value encountered in scalar divide
#   inv_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['inventories'].iloc[i]

# %%
# Create a dataframe that merges all the ratios
ratios = pd.concat([date,tic,OPM,NPM,ROA,ROE,EPS,BPS,DPS,
                    cur_ratio,quick_ratio,cash_ratio,inv_turnover,acc_rec_turnover,acc_pay_turnover,
                   debt_ratio,debt_to_equity], axis=1)

# %%
# Check the ratio data
ratios.head()
# ratios.tail()
# Out:
#         date  tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 0 1999-06-30  AXP       NaN       NaN       NaN       NaN  2.73  21.741648
# 1 1999-09-30  AXP       NaN       NaN       NaN       NaN  4.18  21.769437
# 2 1999-12-31  AXP       NaN       NaN       NaN       NaN  5.54  22.588946
# 3 2000-03-31  AXP  0.154281  0.110742  0.012611  0.185312  1.48  23.055993
# 4 2000-06-30  AXP  0.151641  0.108436  0.012857  0.181749  1.05   7.883721
#
#      DPS  cur_ratio  quick_ratio  cash_ratio inv_turnover acc_rec_turnover  \
# 0  0.225        NaN          NaN         NaN          NaN              NaN
# 1  0.225        NaN          NaN         NaN          NaN              NaN
# 2  0.225        NaN          NaN         NaN          NaN              NaN
# 3  0.225        NaN          NaN         NaN    46.063492         0.319717
# 4  0.080        NaN          NaN         NaN    57.252874         0.324467
#
#   acc_pay_turnover  debt_ratio  debt_to_equity
# 0              NaN    0.926298       12.568121
# 1              NaN    0.926525       12.610016
# 2              NaN    0.932028       13.711937
# 3         0.550059    0.931947       13.694431
# 4         0.505925    0.929258       13.135788

# %%
# Replace NAs infinite values with zero
final_ratios = ratios.copy()
final_ratios = final_ratios.fillna(0)
final_ratios = final_ratios.replace(np.inf,0)

# %%
final_ratios.head()
final_ratios.tail()
# Out:
#            date tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 2451 2020-03-31   V  0.667517  0.521213  0.129058  0.271736  2.85  13.647142
# 2452 2020-06-30   V  0.668385  0.519867  0.120448  0.264075  3.92  14.203947
# 2453 2020-09-30   V  0.654464  0.521290  0.107873  0.241066  4.90  14.653484
# 2454 2020-12-31   V  0.638994  0.480876  0.094422  0.201545  1.42  15.908283
# 2455 2021-03-31   V  0.640128  0.488704  0.095218  0.202568  2.80  16.088525
#
#        DPS  cur_ratio  quick_ratio  cash_ratio  inv_turnover  \
# 2451  0.30   1.248714     1.140070    0.955150           0.0
# 2452  0.30   1.553478     1.443292    1.221925           0.0
# 2453  0.30   1.905238     1.784838    1.579807           0.0
# 2454  0.32   2.121065     1.969814    1.700081           0.0
# 2455  0.32   2.116356     1.954292    1.700574           0.0
#
#       acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity
# 2451          6.116350          2.697537    0.525062        1.105537
# 2452          5.063131          1.889507    0.543886        1.192433
# 2453          5.628571          2.730366    0.552515        1.234714
# 2454          4.725314          2.347866    0.531507        1.134505
# 2455          4.844961          2.367357    0.529946        1.127414

# %%
list_ticker = df["tic"].unique().tolist()
list_date = list(pd.date_range(df['date'].min(),df['date'].max()))
combination = list(itertools.product(list_date,list_ticker))

# Merge stock price data and ratios into one dataframe
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(df,on=["date","tic"],how="left")
processed_full = processed_full.merge(final_ratios,how='left',on=['date','tic'])
processed_full = processed_full.sort_values(['tic','date'])

# Backfill the ratio data to make them daily
processed_full = processed_full.bfill(axis='rows')

# %%
# Calculate P/E, P/B and dividend yield using daily closing price
processed_full['PE'] = processed_full['close']/processed_full['EPS']
processed_full['PB'] = processed_full['close']/processed_full['BPS']
processed_full['Div_yield'] = processed_full['DPS']/processed_full['close']

# Drop per share items used for the above calculation
processed_full = processed_full.drop(columns=['day','EPS','BPS','DPS'])
# Replace NAs infinite values with zero
processed_full = processed_full.copy()
processed_full = processed_full.fillna(0)
processed_full = processed_full.replace(np.inf,0)

# %%
# Check the final data
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#         date   tic       open       high        low      close       volume  \
# 0 2009-01-02  AAPL   3.067143   3.251429   3.041429   2.747390  746015200.0
# 1 2009-01-02  AMGN  58.590000  59.080002  57.750000  42.737896    6547900.0
# 2 2009-01-02   AXP  18.570000  19.520000  18.400000  15.193850   10955700.0
# 3 2009-01-02    BA  42.799999  45.560001  42.779999  33.941101    7010200.0
# 4 2009-01-02   CAT  44.910000  46.980000  44.709999  31.093391    7117200.0
# 5 2009-01-02   CRM   8.025000   8.550000   7.912500   8.505000    4069200.0
# 6 2009-01-02  CSCO  16.410000  17.000000  16.250000  11.685606   40980600.0
# 7 2009-01-02   CVX  74.230003  77.300003  73.580002  42.397469   13695900.0
# 8 2009-01-02   DIS  22.760000  24.030001  22.500000  20.530584    9796600.0
# 9 2009-01-02   DOW  52.750000  53.500000  49.500000  38.707413    2350800.0
#
#         OPM       NPM       ROA  ...  quick_ratio  cash_ratio  inv_turnover  \
# 0  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 1  0.093973  0.072040  0.014094  ...     0.000000    0.000000      0.000000
# 2  0.093973  0.072040  0.014094  ...     0.000000    0.000000      0.000000
# 3  0.047307  0.032525  0.026400  ...     0.368463    0.148507      2.329670
# 4  0.124545  0.066662  0.040891  ...     0.890488    0.163158      3.540791
# 5  0.234698  0.196418  0.097593  ...     2.498162    2.170759      9.054201
# 6  0.234698  0.196418  0.097593  ...     2.498162    2.170759      9.054201
# 7  0.141417  0.097223  0.117691  ...     0.952878    0.373760     23.920348
# 8  0.167221  0.102157  0.045834  ...     0.815629    0.330748     11.310223
# 9  0.000000  0.000000  0.000000  ...     0.000000    0.000000      0.000000
#
#    acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity          PE  \
# 0          8.972003          4.269115    0.437727        0.778495    0.631584
# 1          0.351354          0.653355    0.869784        6.679531  137.864181
# 2          0.351354          0.653355    0.869784        6.679531   49.012418
# 3          6.815203          2.076967    1.009198     -109.722986   39.012760
# 4          2.460351          8.472455    0.893715        9.089489 -163.649429
# 5          6.844634         16.036800    0.400215        0.667591   13.500000
# 6          6.844634         16.036800    0.400215        0.667591   18.548581
# 7         13.387209         11.276861    0.449174        0.815455   46.084205
# 8          5.725855          4.287167    0.455848        0.837721   25.988081
# 9          0.000000          0.000000    0.000000        0.000000  168.293099
#
#           PB  Div_yield
# 0   0.100795   0.000000
# 1   3.957966   0.004212
# 2   1.407106   0.011847
# 3 -35.751054   0.012374
# 4   3.001156   0.013508
# 5   1.351255   0.000000
# 6   1.856583   0.000000
# 7   0.973429   0.015331
# 8   1.122851   0.017048
# 9   0.000000   0.000000
#
# [10 rows x 22 columns]

# %%
train_data = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
# Check the length of the two datasets
print(len(train_data))
print(len(trade_data))
# Out:
# 109530
# 21930

# %%
train_data.head()
# Out:
#         date   tic       open       high        low      close       volume  \
# 0 2009-01-02  AAPL   3.067143   3.251429   3.041429   2.747390  746015200.0
# 0 2009-01-02  AMGN  58.590000  59.080002  57.750000  42.737896    6547900.0
# 0 2009-01-02   AXP  18.570000  19.520000  18.400000  15.193850   10955700.0
# 0 2009-01-02    BA  42.799999  45.560001  42.779999  33.941101    7010200.0
# 0 2009-01-02   CAT  44.910000  46.980000  44.709999  31.093391    7117200.0
#
#         OPM       NPM       ROA  ...  quick_ratio  cash_ratio  inv_turnover  \
# 0  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 0  0.093973  0.072040  0.014094  ...     0.000000    0.000000      0.000000
# 0  0.093973  0.072040  0.014094  ...     0.000000    0.000000      0.000000
# 0  0.047307  0.032525  0.026400  ...     0.368463    0.148507      2.329670
# 0  0.124545  0.066662  0.040891  ...     0.890488    0.163158      3.540791
#
#    acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity          PE  \
# 0          8.972003          4.269115    0.437727        0.778495    0.631584
# 0          0.351354          0.653355    0.869784        6.679531  137.864181
# 0          0.351354          0.653355    0.869784        6.679531   49.012418
# 0          6.815203          2.076967    1.009198     -109.722986   39.012760
# 0          2.460351          8.472455    0.893715        9.089489 -163.649429
#
#           PB  Div_yield
# 0   0.100795   0.000000
# 0   3.957966   0.004212
# 0   1.407106   0.011847
# 0 -35.751054   0.012374
# 0   3.001156   0.013508
#
# [5 rows x 22 columns]

# %%
trade_data.head()
# Out:
#         date   tic        open        high         low       close  \
# 0 2019-01-01  AAPL   38.722500   39.712502   38.557499   37.893330
# 0 2019-01-01  AMGN  192.520004  193.199997  188.949997  164.698090
# 0 2019-01-01   AXP   93.910004   96.269997   93.769997   89.085640
# 0 2019-01-01    BA  316.190002  323.950012  313.709991  314.645111
# 0 2019-01-01   CAT  124.029999  127.879997  123.000000  111.886887
#
#         volume       OPM       NPM       ROA  ...  quick_ratio  cash_ratio  \
# 0  148158800.0  0.258891  0.227773  0.133360  ...     1.134347    0.854114
# 0    3009100.0  0.093973  0.072040  0.014094  ...     0.000000    0.000000
# 0    4175400.0  0.203479  0.160494  0.026811  ...     0.000000    0.000000
# 0    3292200.0  0.116496  0.102682  0.066409  ...     0.262465    0.092436
# 0    4783200.0  0.186871  0.107064  0.056932  ...     0.919490    0.266175
#
#    inv_turnover  acc_rec_turnover  acc_pay_turnover  debt_ratio  \
# 0     23.571867          7.620024          3.781658    0.690466
# 0      0.000000          0.351354          0.653355    0.869784
# 0      0.000000          0.231669          0.279424    0.887329
# 0      0.933164          5.468453          4.151637    0.998070
# 0      2.135008          2.339630          3.660183    0.803394
#
#    debt_to_equity          PE           PB  Div_yield
# 0        2.230663    5.655721     1.649210   0.019265
# 0        6.679531  531.284160    15.252725   0.001093
# 0        7.875371   49.218586     3.356048   0.004378
# 0      517.142241   83.019818  1418.196133   0.006531
# 0        4.086316   34.008172     4.143678   0.007686
#
# [5 rows x 22 columns]

# %%
import gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gym import spaces
from gym.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv

matplotlib.use("Agg")

# from stable_baselines3.common import logger


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        turbulence_threshold=None,
        risk_indicator_col="turbulence",
        make_plots=False,
        print_verbosity=10,
        day=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="", 
    ):
        self.day = day
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        self.data = self.df.loc[self.day, :]
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        self.turbulence_threshold = turbulence_threshold
        self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        # memorize all the total balance change
        self.asset_memory = [self.initial_amount]
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        # self.reset()
        self._seed()

    def _sell_stock(self, index, action):
        def _do_sell_normal():
            if self.state[index + 1] > 0:
                # Sell only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                if self.state[index + self.stock_dim + 1] > 0:
                    # Sell only if current asset is > 0
                    sell_num_shares = min(
                        abs(action), self.state[index + self.stock_dim + 1]
                    )
                    sell_amount = (
                        self.state[index + 1]
                        * sell_num_shares
                        * (1 - self.sell_cost_pct)
                    )
                    # update balance
                    self.state[0] += sell_amount

                    self.state[index + self.stock_dim + 1] -= sell_num_shares
                    self.cost += (
                        self.state[index + 1] * sell_num_shares * self.sell_cost_pct
                    )
                    self.trades += 1
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = 0

            return sell_num_shares

        # perform sell action based on the sign of the action
        if self.turbulence_threshold is not None:
            if self.turbulence >= self.turbulence_threshold:
                if self.state[index + 1] > 0:
                    # Sell only if the price is > 0 (no missing data in this particular date)
                    # if turbulence goes over threshold, just clear out all positions
                    if self.state[index + self.stock_dim + 1] > 0:
                        # Sell only if current asset is > 0
                        sell_num_shares = self.state[index + self.stock_dim + 1]
                        sell_amount = (
                            self.state[index + 1]
                            * sell_num_shares
                            * (1 - self.sell_cost_pct)
                        )
                        # update balance
                        self.state[0] += sell_amount
                        self.state[index + self.stock_dim + 1] = 0
                        self.cost += (
                            self.state[index + 1] * sell_num_shares * self.sell_cost_pct
                        )
                        self.trades += 1
                    else:
                        sell_num_shares = 0
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = _do_sell_normal()
        else:
            sell_num_shares = _do_sell_normal()

        return sell_num_shares

    def _buy_stock(self, index, action):
        def _do_buy():
            if self.state[index + 1] > 0:
                # Buy only if the price is > 0 (no missing data in this particular date)
                available_amount = self.state[0] // self.state[index + 1]
                # print('available_amount:{}'.format(available_amount))

                # update balance
                buy_num_shares = min(available_amount, action)
                buy_amount = (
                    self.state[index + 1] * buy_num_shares * (1 + self.buy_cost_pct)
                )
                self.state[0] -= buy_amount

                self.state[index + self.stock_dim + 1] += buy_num_shares

                self.cost += self.state[index + 1] * buy_num_shares * self.buy_cost_pct
                self.trades += 1
            else:
                buy_num_shares = 0

            return buy_num_shares

        # perform buy action based on the sign of the action
        if self.turbulence_threshold is None:
            buy_num_shares = _do_buy()
        else:
            if self.turbulence < self.turbulence_threshold:
                buy_num_shares = _do_buy()
            else:
                buy_num_shares = 0
                pass

        return buy_num_shares

    def _make_plot(self):
        plt.plot(self.asset_memory, "r")
        plt.savefig("results/account_value_trade_{}.png".format(self.episode))
        plt.close()

    def step(self, actions):
        self.terminal = self.day >= len(self.df.index.unique()) - 1
        if self.terminal:
            # print(f"Episode: {self.episode}")
            if self.make_plots:
                self._make_plot()
            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            df_total_value = pd.DataFrame(self.asset_memory)
            tot_reward = (
                self.state[0]
                + sum(
                    np.array(self.state[1 : (self.stock_dim + 1)])
                    * np.array(
                        self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                    )
                )
                - self.initial_amount
            )
            df_total_value.columns = ["account_value"]
            df_total_value["date"] = self.date_memory
            df_total_value["daily_return"] = df_total_value["account_value"].pct_change(
                1
            )
            if df_total_value["daily_return"].std() != 0:
                sharpe = (
                    (252 ** 0.5)
                    * df_total_value["daily_return"].mean()
                    / df_total_value["daily_return"].std()
                )
            df_rewards = pd.DataFrame(self.rewards_memory)
            df_rewards.columns = ["account_rewards"]
            df_rewards["date"] = self.date_memory[:-1]
            if self.episode % self.print_verbosity == 0:
                print(f"day: {self.day}, episode: {self.episode}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"total_reward: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost:0.2f}")
                print(f"total_trades: {self.trades}")
                if df_total_value["daily_return"].std() != 0:
                    print(f"Sharpe: {sharpe:0.3f}")
                print("=================================")

            if (self.model_name != "") and (self.mode != ""):
                df_actions = self.save_action_memory()
                df_actions.to_csv(
                    "results/actions_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    )
                )
                df_total_value.to_csv(
                    "results/account_value_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                df_rewards.to_csv(
                    "results/account_rewards_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.plot(self.asset_memory, "r")
                plt.savefig(
                    "results/account_value_{}_{}_{}.png".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.close()

            # Add outputs to logger interface
            # logger.record("environment/portfolio_value", end_total_asset)
            # logger.record("environment/total_reward", tot_reward)
            # logger.record("environment/total_reward_pct", (tot_reward / (end_total_asset - tot_reward)) * 100)
            # logger.record("environment/total_cost", self.cost)
            # logger.record("environment/total_trades", self.trades)

            return self.state, self.reward, self.terminal, {}

        else:

            actions = actions * self.hmax  # actions initially is scaled between 0 to 1
            actions = actions.astype(
                int
            )  # convert into integer because we can't by fraction of shares
            if self.turbulence_threshold is not None:
                if self.turbulence >= self.turbulence_threshold:
                    actions = np.array([-self.hmax] * self.stock_dim)
            begin_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            # print("begin_total_asset:{}".format(begin_total_asset))

            argsort_actions = np.argsort(actions)

            sell_index = argsort_actions[: np.where(actions < 0)[0].shape[0]]
            buy_index = argsort_actions[::-1][: np.where(actions > 0)[0].shape[0]]

            for index in sell_index:
                # print(f"Num shares before: {self.state[index+self.stock_dim+1]}")
                # print(f'take sell action before : {actions[index]}')
                actions[index] = self._sell_stock(index, actions[index]) * (-1)
                # print(f'take sell action after : {actions[index]}')
                # print(f"Num shares after: {self.state[index+self.stock_dim+1]}")

            for index in buy_index:
                # print('take buy action: {}'.format(actions[index]))
                actions[index] = self._buy_stock(index, actions[index])

            self.actions_memory.append(actions)

            # state: s -> s+1
            self.day += 1
            self.data = self.df.loc[self.day, :]
            if self.turbulence_threshold is not None:
                if len(self.df.tic.unique()) == 1:
                    self.turbulence = self.data[self.risk_indicator_col]
                elif len(self.df.tic.unique()) > 1:
                    self.turbulence = self.data[self.risk_indicator_col].values[0]
            self.state = self._update_state()

            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())
            self.reward = end_total_asset - begin_total_asset
            self.rewards_memory.append(self.reward)
            self.reward = self.reward * self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        # initiate state
        self.state = self._initiate_state()

        if self.initial:
            self.asset_memory = [self.initial_amount]
        else:
            previous_total_asset = self.previous_state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(
                    self.previous_state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                )
            )
            self.asset_memory = [previous_total_asset]

        self.day = 0
        self.data = self.df.loc[self.day, :]
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.terminal = False
        # self.iteration=self.iteration
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]

        self.episode += 1

        return self.state

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        if self.initial:
            # For Initial State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.initial_amount]
                    + self.data.close.values.tolist()
                    + [0] * self.stock_dim
                    + sum(
                        [
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ],
                        [],
                    )
                )
            else:
                # for single stock
                state = (
                    [self.initial_amount]
                    + [self.data.close]
                    + [0] * self.stock_dim
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
        else:
            # Using Previous State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.previous_state[0]]
                    + self.data.close.values.tolist()
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum(
                        [
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ],
                        [],
                    )
                )
            else:
                # for single stock
                state = (
                    [self.previous_state[0]]
                    + [self.data.close]
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
        return state

    def _update_state(self):
        if len(self.df.tic.unique()) > 1:
            # for multiple stock
            state = (
                [self.state[0]]
                + self.data.close.values.tolist()
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum(
                    [
                        self.data[tech].values.tolist()
                        for tech in self.tech_indicator_list
                    ],
                    [],
                )
            )

        else:
            # for single stock
            state = (
                [self.state[0]]
                + [self.data.close]
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
            )
        return state

    def _get_date(self):
        if len(self.df.tic.unique()) > 1:
            date = self.data.date.unique()[0]
        else:
            date = self.data.date
        return date

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        # print(len(date_list))
        # print(len(asset_list))
        df_account_value = pd.DataFrame(
            {"date": date_list, "account_value": asset_list}
        )
        return df_account_value

    def save_action_memory(self):
        if len(self.df.tic.unique()) > 1:
            # date and close price length must match actions length
            date_list = self.date_memory[:-1]
            df_date = pd.DataFrame(date_list)
            df_date.columns = ["date"]

            action_list = self.actions_memory
            df_actions = pd.DataFrame(action_list)
            df_actions.columns = self.data.tic.values
            df_actions.index = df_date.date
            # df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        else:
            date_list = self.date_memory[:-1]
            action_list = self.actions_memory
            df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
ratio_list = ['OPM', 'NPM','ROA', 'ROE', 'cur_ratio', 'quick_ratio', 'cash_ratio', 'inv_turnover','acc_rec_turnover', 'acc_pay_turnover', 'debt_ratio', 'debt_to_equity',
       'PE', 'PB', 'Div_yield']

stock_dimension = len(train_data.tic.unique()) # Number of stocks
state_space = 1 + 2*stock_dimension + len(ratio_list)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 30, State Space: 511

# %%
# Parameters for the environment
num_stock_shares = [0] * stock_dimension
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": ratio_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
}

#Establish the training environment using StockTradingEnv() class
e_train_gym = StockTradingEnv(df = train_data, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
from stable_baselines3 import A2C
from stable_baselines3 import DDPG
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import TD3
MODELS = {"a2c": A2C, "ddpg": DDPG, "td3": TD3, "sac": SAC, "ppo": PPO}

# %%
# Set up the agent using DRLAgent() class using the environment created in the previous part
agent = DRLAgent(env = env_train)

if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Model 1: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/ppo/ppo_multi_50000"
if if_using_ppo:
    if not os.path.exists(model_file_path+'.zip'):
        trained_ppo = agent.train_model(model=model_ppo, 
                                    tb_log_name='ppo',
                                    total_timesteps=50000,
                                    ) 
        trained_ppo.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_ppo = MODELS['ppo'].load(model_file_path)
        print("agent loaded from", model_file_path)
# Out:
# -------------------------------------
# | time/              |              |
# |    fps             | 175          |
# |    iterations      | 1            |
# |    time_elapsed    | 11           |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.013357171 |
# -------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 2           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014965681 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | -0.00749    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.96        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0266     |
# |    reward               | 0.83899903  |
# |    std                  | 1           |
# |    value_loss           | 7.37        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 3           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019850282 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.00389     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.5         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.024      |
# |    reward               | 0.9920697   |
# |    std                  | 1           |
# |    value_loss           | 18.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 175        |
# |    iterations           | 4          |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01263055 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.7      |
# |    explained_variance   | 0.00142    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.3        |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0226    |
# |    reward               | 0.07460541 |
# |    std                  | 1          |
# |    value_loss           | 10.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 5          |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01850354 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.7      |
# |    explained_variance   | -0.0245    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 7.49       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0215    |
# |    reward               | 0.17310181 |
# |    std                  | 1.01       |
# |    value_loss           | 18.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 6           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.018419288 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.00792     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.63        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0215     |
# |    reward               | 0.06957104  |
# |    std                  | 1.01        |
# |    value_loss           | 10.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 177          |
# |    iterations           | 7            |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.02382908   |
# |    clip_fraction        | 0.254        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.8        |
# |    explained_variance   | -0.0492      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.56         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.023       |
# |    reward               | -0.016736971 |
# |    std                  | 1.01         |
# |    value_loss           | 13.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 178          |
# |    iterations           | 8            |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.025243144  |
# |    clip_fraction        | 0.288        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.9        |
# |    explained_variance   | 0.0117       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.3         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0191      |
# |    reward               | -0.009892154 |
# |    std                  | 1.01         |
# |    value_loss           | 20.2         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 178           |
# |    iterations           | 9             |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.030189278   |
# |    clip_fraction        | 0.286         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -42.9         |
# |    explained_variance   | -0.0168       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.62          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.0229       |
# |    reward               | -0.0043306216 |
# |    std                  | 1.01          |
# |    value_loss           | 15.3          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 10          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.022585647 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | -0.0104     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.3        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0153     |
# |    reward               | 1.893425    |
# |    std                  | 1.01        |
# |    value_loss           | 30.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 11          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.01773345  |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | -0.0252     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.75        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0191     |
# |    reward               | -0.06760226 |
# |    std                  | 1.02        |
# |    value_loss           | 10.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 179          |
# |    iterations           | 12           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.015482876  |
# |    clip_fraction        | 0.187        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -43          |
# |    explained_variance   | 0.0216       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 30.9         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0122      |
# |    reward               | -0.010005111 |
# |    std                  | 1.02         |
# |    value_loss           | 61.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 179          |
# |    iterations           | 13           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.025998894  |
# |    clip_fraction        | 0.22         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -43.1        |
# |    explained_variance   | 0.00691      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 6.4          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0146      |
# |    reward               | -0.005957474 |
# |    std                  | 1.02         |
# |    value_loss           | 19.3         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 179        |
# |    iterations           | 14         |
# |    time_elapsed         | 159        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02318831 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.1      |
# |    explained_variance   | -0.0333    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 42.8       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0156    |
# |    reward               | 1.5182592  |
# |    std                  | 1.02       |
# |    value_loss           | 76.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 15          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.022707878 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | -0.0304     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.42        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0188     |
# |    reward               | 0.42467958  |
# |    std                  | 1.02        |
# |    value_loss           | 13.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 180        |
# |    iterations           | 16         |
# |    time_elapsed         | 181        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02223501 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.3      |
# |    explained_variance   | 0.0352     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 7.2        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.022     |
# |    reward               | -1.7345198 |
# |    std                  | 1.02       |
# |    value_loss           | 24         |
# ----------------------------------------
# day: 3650, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4310352.02
# total_reward: 3310352.02
# total_cost: 351847.76
# total_trades: 101857
# Sharpe: 0.822
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 17          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.017667606 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.3       |
# |    explained_variance   | -0.0097     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.2        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.014      |
# |    reward               | 0.45139578  |
# |    std                  | 1.03        |
# |    value_loss           | 24.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 18          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.038142193 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.4       |
# |    explained_variance   | 0.00308     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.71        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0232     |
# |    reward               | 0.43928054  |
# |    std                  | 1.03        |
# |    value_loss           | 14.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 180        |
# |    iterations           | 19         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03560686 |
# |    clip_fraction        | 0.261      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.5      |
# |    explained_variance   | 0.0023     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 14         |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0135    |
# |    reward               | -1.0022231 |
# |    std                  | 1.03       |
# |    value_loss           | 29.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 20          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.034562614 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.5       |
# |    explained_variance   | -0.0723     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.84        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0142     |
# |    reward               | -1.1445647  |
# |    std                  | 1.03        |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 180        |
# |    iterations           | 21         |
# |    time_elapsed         | 238        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02419869 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.6      |
# |    explained_variance   | -0.0279    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 27.1       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0143    |
# |    reward               | 2.0967898  |
# |    std                  | 1.04       |
# |    value_loss           | 47.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 22          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.027042951 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.6       |
# |    explained_variance   | 0.00492     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.16        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.014      |
# |    reward               | -1.4604492  |
# |    std                  | 1.04        |
# |    value_loss           | 19          |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 179           |
# |    iterations           | 23            |
# |    time_elapsed         | 262           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.030339496   |
# |    clip_fraction        | 0.277         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -43.7         |
# |    explained_variance   | 0.000154      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 27.1          |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00877      |
# |    reward               | -0.0119430525 |
# |    std                  | 1.04          |
# |    value_loss           | 42.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 179          |
# |    iterations           | 24           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.027085084  |
# |    clip_fraction        | 0.264        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -43.7        |
# |    explained_variance   | 0.0146       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.08         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.01        |
# |    reward               | -0.008106311 |
# |    std                  | 1.04         |
# |    value_loss           | 18.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 178          |
# |    iterations           | 25           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.03556236   |
# |    clip_fraction        | 0.356        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -43.8        |
# |    explained_variance   | -0.0133      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.9         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0118      |
# |    reward               | -0.004885489 |
# |    std                  | 1.04         |
# |    value_loss           | 21.1         |
# ------------------------------------------
# agent saved to trained_models/ppo/ppo_multi_50000

# %% [markdown]
# ### Model 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/ddpg

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/ddpg/ddpg_multi_50000"
if if_using_ddpg:
    if not os.path.exists(model_file_path+'.zip'):
        trained_ddpg = agent.train_model(model=model_ddpg, 
                                tb_log_name='ddpg',
                                total_timesteps=50000)
        trained_ddpg.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_ddpg = MODELS['ddpg'].load(model_file_path)
        print("agent loaded from", model_file_path)
# Out:
# day: 3650, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4235400.48
# total_reward: 3235400.48
# total_cost: 999.00
# total_trades: 62050
# Sharpe: 0.796
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 102      |
# |    time_elapsed    | 143      |
# |    total_timesteps | 14604    |
# | train/             |          |
# |    actor_loss      | -5.86    |
# |    critic_loss     | 246      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10953    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 94       |
# |    time_elapsed    | 309      |
# |    total_timesteps | 29208    |
# | train/             |          |
# |    actor_loss      | -2.99    |
# |    critic_loss     | 5.07     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25557    |
# |    reward          | 0.0      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 91       |
# |    time_elapsed    | 476      |
# |    total_timesteps | 43812    |
# | train/             |          |
# |    actor_loss      | -5.54    |
# |    critic_loss     | 3.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 40161    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 3650, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 4235400.48
# total_reward: 3235400.48
# total_cost: 999.00
# total_trades: 62050
# Sharpe: 0.796
# =================================
# agent saved to trained_models/ddpg/ddpg_multi_50000

# %% [markdown]
# ### Model 3: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/a2c/a2c_multi_50000"
if if_using_a2c:
    if not os.path.exists(model_file_path+'.zip'):
        trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000) 
        trained_a2c.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_a2c = MODELS['a2c'].load(model_file_path)
        print("agent loaded from", model_file_path)
# Out:
# -----------------------------------------
# | time/                 |               |
# |    fps                | 167           |
# |    iterations         | 100           |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 500           |
# | train/                |               |
# |    entropy_loss       | -42.7         |
# |    explained_variance | 0.0652        |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 99            |
# |    policy_loss        | 140           |
# |    reward             | -0.0018988374 |
# |    std                | 1             |
# |    value_loss         | 15.4          |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 168       |
# |    iterations         | 200       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -42.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -50.3     |
# |    reward             | 2.0158305 |
# |    std                | 1.01      |
# |    value_loss         | 38.1      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 168           |
# |    iterations         | 300           |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 1500          |
# | train/                |               |
# |    entropy_loss       | -42.8         |
# |    explained_variance | -0.0196       |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 299           |
# |    policy_loss        | 104           |
# |    reward             | -0.0022914454 |
# |    std                | 1.01          |
# |    value_loss         | 6.87          |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 168       |
# |    iterations         | 400       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 3.55      |
# |    reward             | 1.4565458 |
# |    std                | 1.01      |
# |    value_loss         | 1.29      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 168        |
# |    iterations         | 500        |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -42.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -6.19      |
# |    reward             | -2.2750573 |
# |    std                | 1.01       |
# |    value_loss         | 1.29       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 168        |
# |    iterations         | 600        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -42.9      |
# |    explained_variance | -0.269     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 37.3       |
# |    reward             | -2.2459815 |
# |    std                | 1.01       |
# |    value_loss         | 0.828      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 700       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -43       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -172      |
# |    reward             | 2.1033936 |
# |    std                | 1.01      |
# |    value_loss         | 36.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 800        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -43        |
# |    explained_variance | -0.278     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 77.1       |
# |    reward             | -1.7253088 |
# |    std                | 1.01       |
# |    value_loss         | 4.13       |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 900           |
# |    time_elapsed       | 26            |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -43           |
# |    explained_variance | -197          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | -16.6         |
# |    reward             | -0.0069647804 |
# |    std                | 1.02          |
# |    value_loss         | 0.695         |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 1000       |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -43        |
# |    explained_variance | -0.0281    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 58.3       |
# |    reward             | 0.50492245 |
# |    std                | 1.02       |
# |    value_loss         | 2.46       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 1100       |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -43.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -48.8      |
# |    reward             | 0.12665996 |
# |    std                | 1.02       |
# |    value_loss         | 3.11       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 169         |
# |    iterations         | 1200        |
# |    time_elapsed       | 35          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -43.1       |
# |    explained_variance | -0.567      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | -121        |
# |    reward             | -0.20206559 |
# |    std                | 1.02        |
# |    value_loss         | 7.51        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 1300       |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -43.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -47.2      |
# |    reward             | -2.0412002 |
# |    std                | 1.02       |
# |    value_loss         | 1.31       |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 1400          |
# |    time_elapsed       | 41            |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -43.1         |
# |    explained_variance | 0.0256        |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1399          |
# |    policy_loss        | -246          |
# |    reward             | -0.0044072634 |
# |    std                | 1.02          |
# |    value_loss         | 39.4          |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 1500          |
# |    time_elapsed       | 44            |
# |    total_timesteps    | 7500          |
# | train/                |               |
# |    entropy_loss       | -43.2         |
# |    explained_variance | 0.211         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1499          |
# |    policy_loss        | 21.4          |
# |    reward             | -0.0042858706 |
# |    std                | 1.02          |
# |    value_loss         | 0.555         |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 1600      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -43.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -18.5     |
# |    reward             | 2.2928703 |
# |    std                | 1.02      |
# |    value_loss         | 0.857     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 1700       |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -43.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | -21.2      |
# |    reward             | 0.47930542 |
# |    std                | 1.02       |
# |    value_loss         | 0.421      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 1800      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -43.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 21        |
# |    reward             | -4.047803 |
# |    std                | 1.02      |
# |    value_loss         | 0.811     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 1900       |
# |    time_elapsed       | 56         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -43.2      |
# |    explained_variance | 6e-05      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -255       |
# |    reward             | -3.6089284 |
# |    std                | 1.02       |
# |    value_loss         | 48.9       |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 2000          |
# |    time_elapsed       | 59            |
# |    total_timesteps    | 10000         |
# | train/                |               |
# |    entropy_loss       | -43.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1999          |
# |    policy_loss        | -109          |
# |    reward             | -0.0025314814 |
# |    std                | 1.02          |
# |    value_loss         | 7.42          |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 2100      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -43.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 2.23      |
# |    reward             | 0.3405141 |
# |    std                | 1.02      |
# |    value_loss         | 4.34      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 169         |
# |    iterations         | 2200        |
# |    time_elapsed       | 64          |
# |    total_timesteps    | 11000       |
# | train/                |             |
# |    entropy_loss       | -43.3       |
# |    explained_variance | -0.0171     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2199        |
# |    policy_loss        | -12.7       |
# |    reward             | 0.109731145 |
# |    std                | 1.02        |
# |    value_loss         | 1.43        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 169         |
# |    iterations         | 2300        |
# |    time_elapsed       | 67          |
# |    total_timesteps    | 11500       |
# | train/                |             |
# |    entropy_loss       | -43.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2299        |
# |    policy_loss        | -17.7       |
# |    reward             | 0.009861242 |
# |    std                | 1.02        |
# |    value_loss         | 1.58        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 2400      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -43.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -86.4     |
# |    reward             | 0.6045235 |
# |    std                | 1.02      |
# |    value_loss         | 7.57      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 2500       |
# |    time_elapsed       | 73         |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -43.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | 96.5       |
# |    reward             | -1.2625363 |
# |    std                | 1.02       |
# |    value_loss         | 10.2       |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 2600          |
# |    time_elapsed       | 76            |
# |    total_timesteps    | 13000         |
# | train/                |               |
# |    entropy_loss       | -43.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2599          |
# |    policy_loss        | -51.6         |
# |    reward             | -0.0008595784 |
# |    std                | 1.02          |
# |    value_loss         | 2.01          |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 2700       |
# |    time_elapsed       | 79         |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -43.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | -155       |
# |    reward             | -1.5091887 |
# |    std                | 1.02       |
# |    value_loss         | 27.4       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 169      |
# |    iterations         | 2800     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -43.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 44.9     |
# |    reward             | 0.0      |
# |    std                | 1.02     |
# |    value_loss         | 2.52     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 2900      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -43.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 19.8      |
# |    reward             | 0.2923474 |
# |    std                | 1.02      |
# |    value_loss         | 2.88      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 3000      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -43.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -75.5     |
# |    reward             | 1.0285984 |
# |    std                | 1.02      |
# |    value_loss         | 3.38      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 3100      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -43.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -20.3     |
# |    reward             | 0.5488069 |
# |    std                | 1.02      |
# |    value_loss         | 1.09      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 3200          |
# |    time_elapsed       | 94            |
# |    total_timesteps    | 16000         |
# | train/                |               |
# |    entropy_loss       | -43.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 3199          |
# |    policy_loss        | -148          |
# |    reward             | -0.0006622135 |
# |    std                | 1.03          |
# |    value_loss         | 13.5          |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 3300       |
# |    time_elapsed       | 97         |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -43.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | 86         |
# |    reward             | -4.3234177 |
# |    std                | 1.03       |
# |    value_loss         | 10.4       |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 3400          |
# |    time_elapsed       | 100           |
# |    total_timesteps    | 17000         |
# | train/                |               |
# |    entropy_loss       | -43.4         |
# |    explained_variance | 0.629         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 3399          |
# |    policy_loss        | -175          |
# |    reward             | -0.0070990324 |
# |    std                | 1.03          |
# |    value_loss         | 18.3          |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 3500      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -43.4     |
# |    explained_variance | 0.00066   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -65.2     |
# |    reward             | 6.3456326 |
# |    std                | 1.03      |
# |    value_loss         | 2.67      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 3600      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -43.4     |
# |    explained_variance | 0.181     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 80.1      |
# |    reward             | 1.1642913 |
# |    std                | 1.03      |
# |    value_loss         | 6.97      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 3700      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -43.4     |
# |    explained_variance | 0.01      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -21.3     |
# |    reward             | 0.8292747 |
# |    std                | 1.03      |
# |    value_loss         | 0.343     |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 169          |
# |    iterations         | 3800         |
# |    time_elapsed       | 112          |
# |    total_timesteps    | 19000        |
# | train/                |              |
# |    entropy_loss       | -43.5        |
# |    explained_variance | -0.796       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 3799         |
# |    policy_loss        | 35.6         |
# |    reward             | -0.005187425 |
# |    std                | 1.03         |
# |    value_loss         | 0.768        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 169         |
# |    iterations         | 3900        |
# |    time_elapsed       | 115         |
# |    total_timesteps    | 19500       |
# | train/                |             |
# |    entropy_loss       | -43.5       |
# |    explained_variance | -0.00043    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3899        |
# |    policy_loss        | -6.7        |
# |    reward             | -0.31305817 |
# |    std                | 1.03        |
# |    value_loss         | 0.578       |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 4000          |
# |    time_elapsed       | 118           |
# |    total_timesteps    | 20000         |
# | train/                |               |
# |    entropy_loss       | -43.6         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 3999          |
# |    policy_loss        | -103          |
# |    reward             | -0.0077078715 |
# |    std                | 1.04          |
# |    value_loss         | 5.63          |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 4100       |
# |    time_elapsed       | 120        |
# |    total_timesteps    | 20500      |
# | train/                |            |
# |    entropy_loss       | -43.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4099       |
# |    policy_loss        | 41.9       |
# |    reward             | -1.2969958 |
# |    std                | 1.04       |
# |    value_loss         | 1.24       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 169          |
# |    iterations         | 4200         |
# |    time_elapsed       | 123          |
# |    total_timesteps    | 21000        |
# | train/                |              |
# |    entropy_loss       | -43.6        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4199         |
# |    policy_loss        | 61.8         |
# |    reward             | -0.068586074 |
# |    std                | 1.04         |
# |    value_loss         | 7.48         |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 169      |
# |    iterations         | 4300     |
# |    time_elapsed       | 126      |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -43.6    |
# |    explained_variance | -0.273   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 30.8     |
# |    reward             | 2.097584 |
# |    std                | 1.04     |
# |    value_loss         | 3.31     |
# ------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 4400          |
# |    time_elapsed       | 129           |
# |    total_timesteps    | 22000         |
# | train/                |               |
# |    entropy_loss       | -43.6         |
# |    explained_variance | 0.00336       |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 4399          |
# |    policy_loss        | 71.2          |
# |    reward             | -0.0039965054 |
# |    std                | 1.04          |
# |    value_loss         | 3.84          |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 4500       |
# |    time_elapsed       | 132        |
# |    total_timesteps    | 22500      |
# | train/                |            |
# |    entropy_loss       | -43.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4499       |
# |    policy_loss        | -91.2      |
# |    reward             | -1.8549104 |
# |    std                | 1.04       |
# |    value_loss         | 8.5        |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 4600          |
# |    time_elapsed       | 135           |
# |    total_timesteps    | 23000         |
# | train/                |               |
# |    entropy_loss       | -43.7         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 4599          |
# |    policy_loss        | 7.54          |
# |    reward             | -0.0007936516 |
# |    std                | 1.04          |
# |    value_loss         | 0.573         |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 4700      |
# |    time_elapsed       | 138       |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -43.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | 18.6      |
# |    reward             | 1.4226632 |
# |    std                | 1.04      |
# |    value_loss         | 0.598     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 4800      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -43.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -0.0695   |
# |    reward             | 1.2947209 |
# |    std                | 1.04      |
# |    value_loss         | 0.0782    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 4900      |
# |    time_elapsed       | 144       |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -43.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -59.5     |
# |    reward             | 1.3658327 |
# |    std                | 1.04      |
# |    value_loss         | 5.49      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 5000      |
# |    time_elapsed       | 147       |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -43.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -24.8     |
# |    reward             | 0.1289672 |
# |    std                | 1.04      |
# |    value_loss         | 2.37      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 5100          |
# |    time_elapsed       | 150           |
# |    total_timesteps    | 25500         |
# | train/                |               |
# |    entropy_loss       | -43.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 5099          |
# |    policy_loss        | 217           |
# |    reward             | -0.0024034765 |
# |    std                | 1.04          |
# |    value_loss         | 42            |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 5200          |
# |    time_elapsed       | 153           |
# |    total_timesteps    | 26000         |
# | train/                |               |
# |    entropy_loss       | -43.8         |
# |    explained_variance | 0.00012       |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 5199          |
# |    policy_loss        | 13.6          |
# |    reward             | -0.0021848565 |
# |    std                | 1.04          |
# |    value_loss         | 0.118         |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 5300      |
# |    time_elapsed       | 156       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -43.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -91.4     |
# |    reward             | 0.5409021 |
# |    std                | 1.05      |
# |    value_loss         | 5.44      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 5400      |
# |    time_elapsed       | 159       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -43.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | 24        |
# |    reward             | 1.3545988 |
# |    std                | 1.05      |
# |    value_loss         | 0.716     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 169        |
# |    iterations         | 5500       |
# |    time_elapsed       | 161        |
# |    total_timesteps    | 27500      |
# | train/                |            |
# |    entropy_loss       | -43.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5499       |
# |    policy_loss        | 14.4       |
# |    reward             | 0.38364106 |
# |    std                | 1.05       |
# |    value_loss         | 0.139      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 5600      |
# |    time_elapsed       | 164       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -43.8     |
# |    explained_variance | 5.13e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | 158       |
# |    reward             | 1.4368336 |
# |    std                | 1.04      |
# |    value_loss         | 15.6      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 169           |
# |    iterations         | 5700          |
# |    time_elapsed       | 167           |
# |    total_timesteps    | 28500         |
# | train/                |               |
# |    entropy_loss       | -43.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 5699          |
# |    policy_loss        | -14.3         |
# |    reward             | -0.0036282744 |
# |    std                | 1.05          |
# |    value_loss         | 0.75          |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 5800      |
# |    time_elapsed       | 170       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -43.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | 145       |
# |    reward             | 1.5753766 |
# |    std                | 1.05      |
# |    value_loss         | 15.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 5900      |
# |    time_elapsed       | 173       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -43.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -11       |
# |    reward             | -1.595861 |
# |    std                | 1.05      |
# |    value_loss         | 0.87      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 6000       |
# |    time_elapsed       | 176        |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -43.8      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | 52.3       |
# |    reward             | -1.2907181 |
# |    std                | 1.05       |
# |    value_loss         | 2.18       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 6100      |
# |    time_elapsed       | 179       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -43.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -138      |
# |    reward             | 1.0985602 |
# |    std                | 1.05      |
# |    value_loss         | 10.6      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 170           |
# |    iterations         | 6200          |
# |    time_elapsed       | 182           |
# |    total_timesteps    | 31000         |
# | train/                |               |
# |    entropy_loss       | -43.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 6199          |
# |    policy_loss        | 47.9          |
# |    reward             | -0.0027082348 |
# |    std                | 1.05          |
# |    value_loss         | 2.42          |
# -----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 170      |
# |    iterations         | 6300     |
# |    time_elapsed       | 185      |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -43.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 42.3     |
# |    reward             | 0.0      |
# |    std                | 1.05     |
# |    value_loss         | 1.08     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 170         |
# |    iterations         | 6400        |
# |    time_elapsed       | 187         |
# |    total_timesteps    | 32000       |
# | train/                |             |
# |    entropy_loss       | -43.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6399        |
# |    policy_loss        | -110        |
# |    reward             | -0.16805866 |
# |    std                | 1.05        |
# |    value_loss         | 9.47        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 170      |
# |    iterations         | 6500     |
# |    time_elapsed       | 190      |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -43.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -34.7    |
# |    reward             | 0.0      |
# |    std                | 1.05     |
# |    value_loss         | 1.5      |
# ------------------------------------
# day: 3650, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 3975742.29
# total_reward: 2975742.29
# total_cost: 30934.71
# total_trades: 62119
# Sharpe: 0.787
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 6600      |
# |    time_elapsed       | 193       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -43.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | 94.3      |
# |    reward             | 2.8658323 |
# |    std                | 1.05      |
# |    value_loss         | 8.55      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 170      |
# |    iterations         | 6700     |
# |    time_elapsed       | 196      |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -43.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -16.8    |
# |    reward             | 2.678354 |
# |    std                | 1.05     |
# |    value_loss         | 0.25     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 6800       |
# |    time_elapsed       | 199        |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -43.9      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | -15.7      |
# |    reward             | 0.21920396 |
# |    std                | 1.05       |
# |    value_loss         | 0.514      |
# --------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 170            |
# |    iterations         | 6900           |
# |    time_elapsed       | 202            |
# |    total_timesteps    | 34500          |
# | train/                |                |
# |    entropy_loss       | -44            |
# |    explained_variance | 5.96e-08       |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 6899           |
# |    policy_loss        | 193            |
# |    reward             | -5.3046674e-06 |
# |    std                | 1.05           |
# |    value_loss         | 18.2           |
# ------------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 7000      |
# |    time_elapsed       | 205       |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -43.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | 73.2      |
# |    reward             | 1.1773273 |
# |    std                | 1.05      |
# |    value_loss         | 4.33      |
# -------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 170            |
# |    iterations         | 7100           |
# |    time_elapsed       | 208            |
# |    total_timesteps    | 35500          |
# | train/                |                |
# |    entropy_loss       | -43.9          |
# |    explained_variance | 1.19e-07       |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 7099           |
# |    policy_loss        | -11.5          |
# |    reward             | -0.00037684315 |
# |    std                | 1.05           |
# |    value_loss         | 0.18           |
# ------------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 7200      |
# |    time_elapsed       | 211       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -43.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | 60.9      |
# |    reward             | 1.2425085 |
# |    std                | 1.05      |
# |    value_loss         | 2.45      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 7300       |
# |    time_elapsed       | 214        |
# |    total_timesteps    | 36500      |
# | train/                |            |
# |    entropy_loss       | -43.9      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | -633       |
# |    reward             | -13.633634 |
# |    std                | 1.05       |
# |    value_loss         | 428        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 7400       |
# |    time_elapsed       | 216        |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -43.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | 49.3       |
# |    reward             | -1.8815848 |
# |    std                | 1.05       |
# |    value_loss         | 2.65       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 170      |
# |    iterations         | 7500     |
# |    time_elapsed       | 219      |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -44      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 85.8     |
# |    reward             | 0.0      |
# |    std                | 1.05     |
# |    value_loss         | 4.06     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 170         |
# |    iterations         | 7600        |
# |    time_elapsed       | 222         |
# |    total_timesteps    | 38000       |
# | train/                |             |
# |    entropy_loss       | -44         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7599        |
# |    policy_loss        | 32.2        |
# |    reward             | -0.81161404 |
# |    std                | 1.05        |
# |    value_loss         | 0.74        |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 170            |
# |    iterations         | 7700           |
# |    time_elapsed       | 225            |
# |    total_timesteps    | 38500          |
# | train/                |                |
# |    entropy_loss       | -44            |
# |    explained_variance | -1.19e-07      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 7699           |
# |    policy_loss        | 44.7           |
# |    reward             | -0.00019240813 |
# |    std                | 1.05           |
# |    value_loss         | 1.16           |
# ------------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 7800      |
# |    time_elapsed       | 228       |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -44.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | 289       |
# |    reward             | 1.4112334 |
# |    std                | 1.06      |
# |    value_loss         | 50.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 7900       |
# |    time_elapsed       | 231        |
# |    total_timesteps    | 39500      |
# | train/                |            |
# |    entropy_loss       | -44.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7899       |
# |    policy_loss        | -48.6      |
# |    reward             | -1.3210682 |
# |    std                | 1.06       |
# |    value_loss         | 1.98       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 8000      |
# |    time_elapsed       | 234       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -44       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | 26        |
# |    reward             | 2.4157884 |
# |    std                | 1.05      |
# |    value_loss         | 2.48      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 170           |
# |    iterations         | 8100          |
# |    time_elapsed       | 237           |
# |    total_timesteps    | 40500         |
# | train/                |               |
# |    entropy_loss       | -44.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 8099          |
# |    policy_loss        | 56.6          |
# |    reward             | -0.0008280787 |
# |    std                | 1.06          |
# |    value_loss         | 2.26          |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 8200       |
# |    time_elapsed       | 240        |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -44.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | -48        |
# |    reward             | 0.21671315 |
# |    std                | 1.06       |
# |    value_loss         | 1.38       |
# --------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 170           |
# |    iterations         | 8300          |
# |    time_elapsed       | 243           |
# |    total_timesteps    | 41500         |
# | train/                |               |
# |    entropy_loss       | -44.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 8299          |
# |    policy_loss        | -10.9         |
# |    reward             | -8.913201e-05 |
# |    std                | 1.06          |
# |    value_loss         | 0.115         |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 8400       |
# |    time_elapsed       | 245        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -44.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | 12         |
# |    reward             | 0.55216914 |
# |    std                | 1.06       |
# |    value_loss         | 0.772      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 8500      |
# |    time_elapsed       | 248       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -44.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | -83.6     |
# |    reward             | -0.792061 |
# |    std                | 1.06      |
# |    value_loss         | 6.18      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 8600       |
# |    time_elapsed       | 251        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -44.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 13.6       |
# |    reward             | -3.4350204 |
# |    std                | 1.06       |
# |    value_loss         | 0.23       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 8700      |
# |    time_elapsed       | 254       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -44.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | 53.1      |
# |    reward             | 7.955614  |
# |    std                | 1.06      |
# |    value_loss         | 13.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 8800      |
# |    time_elapsed       | 257       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -44.3     |
# |    explained_variance | -0.0461   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -58.4     |
# |    reward             | 0.9106167 |
# |    std                | 1.06      |
# |    value_loss         | 3.43      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 170      |
# |    iterations         | 8900     |
# |    time_elapsed       | 260      |
# |    total_timesteps    | 44500    |
# | train/                |          |
# |    entropy_loss       | -44.3    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | -113     |
# |    reward             | 0.0      |
# |    std                | 1.06     |
# |    value_loss         | 6.7      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 9000       |
# |    time_elapsed       | 263        |
# |    total_timesteps    | 45000      |
# | train/                |            |
# |    entropy_loss       | -44.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8999       |
# |    policy_loss        | -6.32      |
# |    reward             | -1.5388302 |
# |    std                | 1.07       |
# |    value_loss         | 0.139      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 170       |
# |    iterations         | 9100      |
# |    time_elapsed       | 266       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -44.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -28       |
# |    reward             | 1.0676959 |
# |    std                | 1.07      |
# |    value_loss         | 0.899     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 9200       |
# |    time_elapsed       | 269        |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -44.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | 61.5       |
# |    reward             | -1.6850736 |
# |    std                | 1.07       |
# |    value_loss         | 2.02       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 9300       |
# |    time_elapsed       | 272        |
# |    total_timesteps    | 46500      |
# | train/                |            |
# |    entropy_loss       | -44.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9299       |
# |    policy_loss        | -0.819     |
# |    reward             | -1.2061013 |
# |    std                | 1.07       |
# |    value_loss         | 0.16       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 170          |
# |    iterations         | 9400         |
# |    time_elapsed       | 274          |
# |    total_timesteps    | 47000        |
# | train/                |              |
# |    entropy_loss       | -44.6        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9399         |
# |    policy_loss        | -233         |
# |    reward             | -0.001097695 |
# |    std                | 1.07         |
# |    value_loss         | 28.6         |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 170           |
# |    iterations         | 9500          |
# |    time_elapsed       | 277           |
# |    total_timesteps    | 47500         |
# | train/                |               |
# |    entropy_loss       | -44.6         |
# |    explained_variance | -1.66         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 9499          |
# |    policy_loss        | 755           |
# |    reward             | -0.0022247855 |
# |    std                | 1.07          |
# |    value_loss         | 250           |
# -----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 170      |
# |    iterations         | 9600     |
# |    time_elapsed       | 280      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -44.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9599     |
# |    policy_loss        | 137      |
# |    reward             | 0.422692 |
# |    std                | 1.07     |
# |    value_loss         | 13       |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 9700       |
# |    time_elapsed       | 283        |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -44.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | -58.5      |
# |    reward             | 0.22798017 |
# |    std                | 1.08       |
# |    value_loss         | 4.08       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 9800       |
# |    time_elapsed       | 286        |
# |    total_timesteps    | 49000      |
# | train/                |            |
# |    entropy_loss       | -44.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9799       |
# |    policy_loss        | 24.9       |
# |    reward             | 0.43672916 |
# |    std                | 1.08       |
# |    value_loss         | 0.493      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 170        |
# |    iterations         | 9900       |
# |    time_elapsed       | 289        |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -44.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | -39.3      |
# |    reward             | 0.26748648 |
# |    std                | 1.08       |
# |    value_loss         | 2.91       |
# --------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 170            |
# |    iterations         | 10000          |
# |    time_elapsed       | 292            |
# |    total_timesteps    | 50000          |
# | train/                |                |
# |    entropy_loss       | -44.7          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 9999           |
# |    policy_loss        | -297           |
# |    reward             | -2.0612244e-06 |
# |    std                | 1.08           |
# |    value_loss         | 50.9           |
# ------------------------------------------
# agent saved to trained_models/a2c/a2c_multi_50000

# %% [markdown]
# ### Model 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 300000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 300000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/td3

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/td3/td3_multi_30000"
if if_using_td3:
    if not os.path.exists(model_file_path+'.zip'):
        trained_td3 = agent.train_model(model=model_td3, 
                                tb_log_name='td3',
                                total_timesteps=30000) 
        trained_td3.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_td3 = MODELS['td3'].load(model_file_path)
        print("agent loaded from", model_file_path)
# Out:
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 101      |
# |    time_elapsed    | 143      |
# |    total_timesteps | 14604    |
# | train/             |          |
# |    actor_loss      | 102      |
# |    critic_loss     | 1.63e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10953    |
# |    reward          | 0.0      |
# ---------------------------------
# day: 3650, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 5082688.84
# total_reward: 4082688.84
# total_cost: 999.00
# total_trades: 40150
# Sharpe: 0.846
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 94       |
# |    time_elapsed    | 309      |
# |    total_timesteps | 29208    |
# | train/             |          |
# |    actor_loss      | 45.2     |
# |    critic_loss     | 215      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25557    |
# |    reward          | 0.0      |
# ---------------------------------
# agent saved to trained_models/td3/td3_multi_30000

# %% [markdown]
# ### Model 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to results/sac

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/sac/sac_multi_40000"
if if_using_sac:
    if not os.path.exists(model_file_path+'.zip'):
        trained_sac = agent.train_model(model=model_sac, 
                                tb_log_name='sac',
                                total_timesteps=40000) 
        trained_sac.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_sac = MODELS['sac'].load(model_file_path)
        print("agent loaded from", model_file_path)
# Out:
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 74            |
# |    time_elapsed    | 196           |
# |    total_timesteps | 14604         |
# | train/             |               |
# |    actor_loss      | 352           |
# |    critic_loss     | 24.2          |
# |    ent_coef        | 0.075         |
# |    ent_coef_loss   | -115          |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 14503         |
# |    reward          | -0.0006230328 |
# --------------------------------------
# day: 3650, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 5834577.49
# total_reward: 4834577.49
# total_cost: 25227.39
# total_trades: 74033
# Sharpe: 0.805
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 74           |
# |    time_elapsed    | 393          |
# |    total_timesteps | 29208        |
# | train/             |              |
# |    actor_loss      | 125          |
# |    critic_loss     | 9.98         |
# |    ent_coef        | 0.0176       |
# |    ent_coef_loss   | -162         |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 29107        |
# |    reward          | -0.002057956 |
# -------------------------------------
# agent saved to trained_models/sac/sac_multi_40000

# %%
trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
e_trade_gym = StockTradingEnv(df = trade_data, **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade_data.head()
# Out:
#         date   tic        open        high         low       close  \
# 0 2019-01-01  AAPL   38.722500   39.712502   38.557499   37.893330
# 0 2019-01-01  AMGN  192.520004  193.199997  188.949997  164.698090
# 0 2019-01-01   AXP   93.910004   96.269997   93.769997   89.085640
# 0 2019-01-01    BA  316.190002  323.950012  313.709991  314.645111
# 0 2019-01-01   CAT  124.029999  127.879997  123.000000  111.886887
#
#         volume       OPM       NPM       ROA  ...  quick_ratio  cash_ratio  \
# 0  148158800.0  0.258891  0.227773  0.133360  ...     1.134347    0.854114
# 0    3009100.0  0.093973  0.072040  0.014094  ...     0.000000    0.000000
# 0    4175400.0  0.203479  0.160494  0.026811  ...     0.000000    0.000000
# 0    3292200.0  0.116496  0.102682  0.066409  ...     0.262465    0.092436
# 0    4783200.0  0.186871  0.107064  0.056932  ...     0.919490    0.266175
#
#    inv_turnover  acc_rec_turnover  acc_pay_turnover  debt_ratio  \
# 0     23.571867          7.620024          3.781658    0.690466
# 0      0.000000          0.351354          0.653355    0.869784
# 0      0.000000          0.231669          0.279424    0.887329
# 0      0.933164          5.468453          4.151637    0.998070
# 0      2.135008          2.339630          3.660183    0.803394
#
#    debt_to_equity          PE           PB  Div_yield
# 0        2.230663    5.655721     1.649210   0.019265
# 0        6.679531  531.284160    15.252725   0.001093
# 0        7.875371   49.218586     3.356048   0.004378
# 0      517.142241   83.019818  1418.196133   0.006531
# 0        4.086316   34.008172     4.143678   0.007686
#
# [5 rows x 22 columns]

# %%
if if_using_ppo:
    df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
        model=trained_ppo, 
        environment = e_trade_gym) 

if if_using_ddpg:
    df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
        model=trained_ddpg, 
        environment = e_trade_gym) 
if if_using_a2c:
    df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
        model=trained_a2c, 
        environment = e_trade_gym)
if if_using_td3:
    df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
        model=trained_td3, 
        environment = e_trade_gym)
if if_using_sac:
    df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
        model=trained_sac, 
        environment = e_trade_gym)
# Out:
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# hit end!
# hit end!
# hit end!
# hit end!
# hit end!

# %%
# df_account_value_ppo.shape
# df_account_value_ddpg.shape
# df_account_value_a2c.shape
# df_account_value_td3.shape
# df_account_value_sac.shape

# %%
# df_account_value_ppo.tail()
# df_account_value_ddpg.tail()
# df_account_value_a2c.tail()
# df_account_value_td3.tail()
# df_account_value_sac.tail()

# %%
# df_actions_ppo.head()
# df_actions_ddpg.head()
# df_actions_a2c.head()
# df_actions_td3.head()
# df_actions_sac.head()

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

if if_using_ppo:
  print("\n ppo:")
  perf_stats_all_ppo = backtest_stats(account_value=df_account_value_ppo)
  perf_stats_all_ppo = pd.DataFrame(perf_stats_all_ppo)
  perf_stats_all_ppo.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ppo_"+now+'.csv')

if if_using_ddpg:
  print("\n ddpg:")
  perf_stats_all_ddpg = backtest_stats(account_value=df_account_value_ddpg)
  perf_stats_all_ddpg = pd.DataFrame(perf_stats_all_ddpg)
  perf_stats_all_ddpg.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ddpg_"+now+'.csv')

if if_using_a2c:
  print("\n a2c:")
  perf_stats_all_a2c = backtest_stats(account_value=df_account_value_a2c)
  perf_stats_all_a2c = pd.DataFrame(perf_stats_all_a2c)
  perf_stats_all_a2c.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_a2c_"+now+'.csv')

if if_using_td3:
  print("\n atd3:")
  perf_stats_all_td3 = backtest_stats(account_value=df_account_value_td3)
  perf_stats_all_td3 = pd.DataFrame(perf_stats_all_td3)
  perf_stats_all_td3.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_td3_"+now+'.csv')

if if_using_sac:
  print("\n sac:")
  perf_stats_all_sac = backtest_stats(account_value=df_account_value_sac)
  perf_stats_all_sac = pd.DataFrame(perf_stats_all_sac)
  perf_stats_all_sac.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_sac_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
#
#  ppo:
# Annual return          0.139982
# Cumulative returns     0.462342
# Annual volatility      0.263469
# Sharpe ratio           0.630782
# Calmar ratio           0.345400
# Stability              0.321382
# Max drawdown          -0.405274
# Omega ratio            1.178782
# Sortino ratio          0.881869
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.987865
# Daily value at risk   -0.032535
# dtype: float64
#
#  ddpg:
# Annual return          0.095588
# Cumulative returns     0.303192
# Annual volatility      0.238260
# Sharpe ratio           0.504188
# Calmar ratio           0.247974
# Stability              0.043811
# Max drawdown          -0.385476
# Omega ratio            1.142209
# Sortino ratio          0.689576
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.006753
# Daily value at risk   -0.029541
# dtype: float64
#
#  a2c:
# Annual return          0.092026
# Cumulative returns     0.290941
# Annual volatility      0.236791
# Sharpe ratio           0.491572
# Calmar ratio           0.233122
# Stability              0.000515
# Max drawdown          -0.394757
# Omega ratio            1.133122
# Sortino ratio          0.680273
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.982895
# Daily value at risk   -0.029371
# dtype: float64
#
#  atd3:
# Annual return          0.082577
# Cumulative returns     0.258804
# Annual volatility      0.244965
# Sharpe ratio           0.447768
# Calmar ratio           0.206118
# Stability              0.018728
# Max drawdown          -0.400630
# Omega ratio            1.125184
# Sortino ratio          0.616987
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.931348
# Daily value at risk   -0.030427
# dtype: float64
#
#  sac:
# Annual return          0.098540
# Cumulative returns     0.313403
# Annual volatility      0.245576
# Sharpe ratio           0.507176
# Calmar ratio           0.257189
# Stability              0.031405
# Max drawdown          -0.383141
# Omega ratio            1.141624
# Sortino ratio          0.696817
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.971980
# Daily value at risk   -0.030445
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = TEST_START_DATE,
        end = TEST_END_DATE)

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (505, 8)
# Annual return          0.144674
# Cumulative returns     0.310981
# Annual volatility      0.274619
# Sharpe ratio           0.631418
# Calmar ratio           0.390102
# Stability              0.116677
# Max drawdown          -0.370862
# Omega ratio            1.149365
# Sortino ratio          0.870084
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.860710
# Daily value at risk   -0.033911
# dtype: float64

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX

if if_using_ppo:
  backtest_plot(df_account_value_ppo, 
              baseline_ticker = '^DJI', 
              baseline_start = TEST_START_DATE,
              baseline_end = TEST_END_DATE)

# if if_using_ddpg:
#   backtest_plot(df_account_value_ddpg, 
#               baseline_ticker = '^DJI', 
#               baseline_start = TEST_START_DATE,
#               baseline_end = TEST_END_DATE)

# if if_using_a2c:
#   backtest_plot(df_account_value_a2c, 
#               baseline_ticker = '^DJI', 
#               baseline_start = TEST_START_DATE,
#               baseline_end = TEST_END_DATE)

# if if_using_td3:
#   backtest_plot(df_account_value_td3, 
#               baseline_ticker = '^DJI', 
#               baseline_start = TEST_START_DATE,
#               baseline_end = TEST_END_DATE)

# if if_using_sac:
#   print(df_account_value_sac.head())
#   print(type(df_account_value_sac))
#   backtest_plot(df_account_value_sac, 
#               baseline_ticker = '^DJI', 
#               baseline_start = TEST_START_DATE,
#               baseline_end = TEST_END_DATE)
# Out:
# ==============Compare to DJIA===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (505, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>34</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>13.998%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>46.234%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>26.347%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.63</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-40.527%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.18</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.253%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.08</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.76</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>40.53</td>
#       <td>2020-01-17</td>
#       <td>2020-03-23</td>
#       <td>2020-11-07</td>
#       <td>211</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8.98</td>
#       <td>2019-07-26</td>
#       <td>2019-08-23</td>
#       <td>2019-11-15</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>6.13</td>
#       <td>2019-04-27</td>
#       <td>2019-06-03</td>
#       <td>2019-06-20</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.85</td>
#       <td>2019-11-27</td>
#       <td>2019-12-03</td>
#       <td>2019-12-06</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.67</td>
#       <td>2019-03-16</td>
#       <td>2019-03-25</td>
#       <td>2019-04-05</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/pyfolio/plotting.py:1304: UserWarning: The palette list has more values (3) than needed (1), which may not be intended.
#   sns.boxplot(data=[is_returns, is_weekly, is_monthly],
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/pyfolio/plotting.py:1320: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Daily', 'Weekly', 'Monthly'])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.07%</td>
#       <td>-14.19%</td>
#       <td>12.65%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_results = {'ppo': df_account_value_ppo, 'ddpg': df_account_value_ddpg, 'a2c': df_account_value_a2c, 'td3': df_account_value_td3, 'sac': df_account_value_sac}

# Generate a list of distinct colors using a colormap
colors = ['r', 'g', 'b', 'y']

plt.figure(figsize=(10, 6))

for (model, result), color in zip(model_results.items(), colors):
    cumulative_return = ((result['account_value'] / result['account_value'].iloc[0]) - 1) * 100
    plt.plot(result['date'], cumulative_return, marker='o', linestyle='-', label=model, color=color)

plt.xlabel('Date')
plt.ylabel('Cumulative Return (%)')
plt.grid(True)
plt.legend()
plt.show()
