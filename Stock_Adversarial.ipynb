# %%
## install finrl library
## !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import pandas as pd
print(pd.__version__)
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
import os
from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from finrl.main import check_and_make_directories
from pprint import pprint
from stable_baselines3.common.logger import configure
import sys
sys.path.append("../FinRL")

import itertools

from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

from finrl.config_tickers import DOW_30_TICKER
# Out:
# 1.3.5

# %%
from stable_baselines3 import A2C
from stable_baselines3 import DDPG
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import TD3
MODELS = {"a2c": A2C, "ddpg": DDPG, "td3": TD3, "sac": SAC, "ppo": PPO}

# %%
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
print(DOW_30_TICKER)
DOW_30_TICKER = ['AAPL'] # Restrict Trading to one stock
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2019-01-01'
TEST_START_DATE = '2019-01-01'
TEST_END_DATE = '2021-01-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (3021, 8)

# %%
df.shape
# Out:
# (3021, 8)

# %%
df.head()
# Out:
#          date      open      high       low     close      volume   tic  day
# 0  2009-01-02  3.067143  3.251429  3.041429  2.747391   746015200  AAPL    4
# 1  2009-01-05  3.327500  3.435000  3.311071  2.863342  1181608400  AAPL    0
# 2  2009-01-06  3.426786  3.470357  3.299643  2.816113  1289310400  AAPL    1
# 3  2009-01-07  3.278929  3.303571  3.223571  2.755262   753048800  AAPL    2
# 4  2009-01-08  3.229643  3.326786  3.215714  2.806425   673500800  AAPL    3

# %%
df['date'] = pd.to_datetime(df['date'],format='%Y-%m-%d')

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#         date      open      high       low     close      volume   tic  day
# 0 2009-01-02  3.067143  3.251429  3.041429  2.747391   746015200  AAPL    4
# 1 2009-01-05  3.327500  3.435000  3.311071  2.863342  1181608400  AAPL    0
# 2 2009-01-06  3.426786  3.470357  3.299643  2.816113  1289310400  AAPL    1
# 3 2009-01-07  3.278929  3.303571  3.223571  2.755262   753048800  AAPL    2
# 4 2009-01-08  3.229643  3.326786  3.215714  2.806425   673500800  AAPL    3

# %%
# Import fundamental data from my GitHub repository
url = 'https://raw.githubusercontent.com/mariko-sawada/FinRL_with_fundamental_data/main/dow_30_fundamental_wrds.csv'

fund = pd.read_csv(url)
# Out:
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3550: DtypeWarning: Columns (16,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Check the imported dataset
fund.head()
# Out:
#    gvkey  datadate  fyearq  fqtr  fyr indfmt consol popsrc datafmt  tic  ...  \
# 0   1447  19990630    1999     2   12   INDL      C      D     STD  AXP  ...
# 1   1447  19990930    1999     3   12   INDL      C      D     STD  AXP  ...
# 2   1447  19991231    1999     4   12   INDL      C      D     STD  AXP  ...
# 3   1447  20000331    2000     1   12   INDL      C      D     STD  AXP  ...
# 4   1447  20000630    2000     2   12   INDL      C      D     STD  AXP  ...
#
#   dvpsxq mkvaltq     prccq     prchq     prclq  adjex ggroup    gind gsector  \
# 0  0.225     NaN  130.1250  142.6250  114.5000    3.0   4020  402020      40
# 1  0.000     NaN  135.0000  150.6250  121.8750    3.0   4020  402020      40
# 2  0.225     NaN  166.2500  168.8750  130.2500    3.0   4020  402020      40
# 3  0.225     NaN  148.9375  169.5000  119.5000    3.0   4020  402020      40
# 4  0.080     NaN   52.1250   57.1875   43.9375    1.0   4020  402020      40
#
#     gsubind
# 0  40202010
# 1  40202010
# 2  40202010
# 3  40202010
# 4  40202010
#
# [5 rows x 647 columns]

# %%
# List items that are used to calculate financial ratios

items = [
    'datadate', # Date
    'tic', # Ticker
    'oiadpq', # Quarterly operating income
    'revtq', # Quartely revenue
    'niq', # Quartely net income
    'atq', # Total asset
    'teqq', # Shareholder's equity
    'epspiy', # EPS(Basic) incl. Extraordinary items
    'ceqq', # Common Equity
    'cshoq', # Common Shares Outstanding
    'dvpspq', # Dividends per share
    'actq', # Current assets
    'lctq', # Current liabilities
    'cheq', # Cash & Equivalent
    'rectq', # Recievalbles
    'cogsq', # Cost of  Goods Sold
    'invtq', # Inventories
    'apq',# Account payable
    'dlttq', # Long term debt
    'dlcq', # Debt in current liabilites
    'ltq' # Liabilities   
]

# Omit items that will not be used
fund_data = fund[items]

# %%
# Rename column names for the sake of readability
fund_data = fund_data.rename(columns={
    'datadate':'date', # Date
    'oiadpq':'op_inc_q', # Quarterly operating income
    'revtq':'rev_q', # Quartely revenue
    'niq':'net_inc_q', # Quartely net income
    'atq':'tot_assets', # Assets
    'teqq':'sh_equity', # Shareholder's equity
    'epspiy':'eps_incl_ex', # EPS(Basic) incl. Extraordinary items
    'ceqq':'com_eq', # Common Equity
    'cshoq':'sh_outstanding', # Common Shares Outstanding
    'dvpspq':'div_per_sh', # Dividends per share
    'actq':'cur_assets', # Current assets
    'lctq':'cur_liabilities', # Current liabilities
    'cheq':'cash_eq', # Cash & Equivalent
    'rectq':'receivables', # Receivalbles
    'cogsq':'cogs_q', # Cost of  Goods Sold
    'invtq':'inventories', # Inventories
    'apq': 'payables',# Account payable
    'dlttq':'long_debt', # Long term debt
    'dlcq':'short_debt', # Debt in current liabilites
    'ltq':'tot_liabilities' # Liabilities   
})

# %%
# Check the data
fund_data.head()
# Out:
#        date  tic  op_inc_q   rev_q  net_inc_q  tot_assets  sh_equity  \
# 0  19990630  AXP     896.0  5564.0      646.0    132452.0     9762.0
# 1  19990930  AXP     906.0  5584.0      648.0    132616.0     9744.0
# 2  19991231  AXP     845.0  6009.0      606.0    148517.0    10095.0
# 3  20000331  AXP     920.0  6021.0      656.0    150662.0    10253.0
# 4  20000630  AXP    1046.0  6370.0      740.0    148553.0    10509.0
#
#    eps_incl_ex   com_eq  sh_outstanding  ...  cur_assets  cur_liabilities  \
# 0         2.73   9762.0           449.0  ...         NaN              NaN
# 1         4.18   9744.0           447.6  ...         NaN              NaN
# 2         5.54  10095.0           446.9  ...         NaN              NaN
# 3         1.48  10253.0           444.7  ...         NaN              NaN
# 4         1.05  10509.0          1333.0  ...         NaN              NaN
#
#    cash_eq  receivables  cogs_q  inventories  payables  long_debt  short_debt  \
# 0   6096.0      46774.0  4668.0        448.0   22282.0     7005.0     24785.0
# 1   5102.0      48827.0  4678.0        284.0   23587.0     6720.0     24683.0
# 2  10391.0      54033.0  5164.0        277.0   25719.0     4685.0     32437.0
# 3   7425.0      53663.0  5101.0        315.0   26379.0     5670.0     29342.0
# 4   6841.0      54286.0  5324.0        261.0   29536.0     5336.0     26170.0
#
#    tot_liabilities
# 0         122690.0
# 1         122872.0
# 2         138422.0
# 3         140409.0
# 4         138044.0
#
# [5 rows x 21 columns]

# %%
# Calculate financial ratios
date = pd.to_datetime(fund_data['date'],format='%Y%m%d')

tic = fund_data['tic'].to_frame('tic')

# Profitability ratios
# Operating Margin
OPM = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='OPM')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        OPM[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        OPM.iloc[i] = np.nan
    else:
        OPM.iloc[i] = np.sum(fund_data['op_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])

# Net Profit Margin        
NPM = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='NPM')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        NPM[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        NPM.iloc[i] = np.nan
    else:
        NPM.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])

# Return On Assets
ROA = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='ROA')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        ROA[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        ROA.iloc[i] = np.nan
    else:
        ROA.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/fund_data['tot_assets'].iloc[i]

# Return on Equity
ROE = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='ROE')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        ROE[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        ROE.iloc[i] = np.nan
    else:
        ROE.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/fund_data['sh_equity'].iloc[i]        

# For calculating valuation ratios in the next subpart, calculate per share items in advance
# Earnings Per Share       
EPS = fund_data['eps_incl_ex'].to_frame('EPS')

# Book Per Share
BPS = (fund_data['com_eq']/fund_data['sh_outstanding']).to_frame('BPS') # Need to check units

#Dividend Per Share
DPS = fund_data['div_per_sh'].to_frame('DPS')

# Liquidity ratios
# Current ratio
cur_ratio = (fund_data['cur_assets']/fund_data['cur_liabilities']).to_frame('cur_ratio')

# Quick ratio
quick_ratio = ((fund_data['cash_eq'] + fund_data['receivables'] )/fund_data['cur_liabilities']).to_frame('quick_ratio')

# Cash ratio
cash_ratio = (fund_data['cash_eq']/fund_data['cur_liabilities']).to_frame('cash_ratio')


# Efficiency ratios
# Inventory turnover ratio
inv_turnover = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='inv_turnover')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        inv_turnover[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        inv_turnover.iloc[i] = np.nan
    else:
        inv_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['inventories'].iloc[i]

# Receivables turnover ratio       
acc_rec_turnover = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='acc_rec_turnover')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        acc_rec_turnover[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        acc_rec_turnover.iloc[i] = np.nan
    else:
        acc_rec_turnover.iloc[i] = np.sum(fund_data['rev_q'].iloc[i-3:i])/fund_data['receivables'].iloc[i]

# Payable turnover ratio
acc_pay_turnover = pd.Series(np.empty(fund_data.shape[0],dtype=object),name='acc_pay_turnover')
for i in range(0, fund_data.shape[0]):
    if i-3 < 0:
        acc_pay_turnover[i] = np.nan
    elif fund_data.iloc[i,1] != fund_data.iloc[i-3,1]:
        acc_pay_turnover.iloc[i] = np.nan
    else:
        acc_pay_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['payables'].iloc[i]
        
## Leverage financial ratios
# Debt ratio
debt_ratio = (fund_data['tot_liabilities']/fund_data['tot_assets']).to_frame('debt_ratio')

# Debt to Equity ratio
debt_to_equity = (fund_data['tot_liabilities']/fund_data['sh_equity']).to_frame('debt_to_equity')
# Out:
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_82822/22741674.py:15: RuntimeWarning: divide by zero encountered in scalar divide
#   OPM.iloc[i] = np.sum(fund_data['op_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_82822/22741674.py:15: RuntimeWarning: invalid value encountered in scalar divide
#   OPM.iloc[i] = np.sum(fund_data['op_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_82822/22741674.py:25: RuntimeWarning: divide by zero encountered in scalar divide
#   NPM.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_82822/22741674.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   NPM.iloc[i] = np.sum(fund_data['net_inc_q'].iloc[i-3:i])/np.sum(fund_data['rev_q'].iloc[i-3:i])
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_82822/22741674.py:77: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['inventories'].iloc[i]
# /var/folders/tm/wqys1qtx3vd03c0wc2ns9vc40000gn/T/ipykernel_82822/22741674.py:77: RuntimeWarning: invalid value encountered in scalar divide
#   inv_turnover.iloc[i] = np.sum(fund_data['cogs_q'].iloc[i-3:i])/fund_data['inventories'].iloc[i]

# %%
# Create a dataframe that merges all the ratios
ratios = pd.concat([date,tic,OPM,NPM,ROA,ROE,EPS,BPS,DPS,
                    cur_ratio,quick_ratio,cash_ratio,inv_turnover,acc_rec_turnover,acc_pay_turnover,
                   debt_ratio,debt_to_equity], axis=1)

# %%
# Check the ratio data
ratios.head()
# ratios.tail()
# Out:
#         date  tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 0 1999-06-30  AXP       NaN       NaN       NaN       NaN  2.73  21.741648
# 1 1999-09-30  AXP       NaN       NaN       NaN       NaN  4.18  21.769437
# 2 1999-12-31  AXP       NaN       NaN       NaN       NaN  5.54  22.588946
# 3 2000-03-31  AXP  0.154281  0.110742  0.012611  0.185312  1.48  23.055993
# 4 2000-06-30  AXP  0.151641  0.108436  0.012857  0.181749  1.05   7.883721
#
#      DPS  cur_ratio  quick_ratio  cash_ratio inv_turnover acc_rec_turnover  \
# 0  0.225        NaN          NaN         NaN          NaN              NaN
# 1  0.225        NaN          NaN         NaN          NaN              NaN
# 2  0.225        NaN          NaN         NaN          NaN              NaN
# 3  0.225        NaN          NaN         NaN    46.063492         0.319717
# 4  0.080        NaN          NaN         NaN    57.252874         0.324467
#
#   acc_pay_turnover  debt_ratio  debt_to_equity
# 0              NaN    0.926298       12.568121
# 1              NaN    0.926525       12.610016
# 2              NaN    0.932028       13.711937
# 3         0.550059    0.931947       13.694431
# 4         0.505925    0.929258       13.135788

# %%
# Replace NAs infinite values with zero
final_ratios = ratios.copy()
final_ratios = final_ratios.fillna(0)
final_ratios = final_ratios.replace(np.inf,0)

# %%
final_ratios.head()
final_ratios.tail()
# Out:
#            date tic       OPM       NPM       ROA       ROE   EPS        BPS  \
# 2451 2020-03-31   V  0.667517  0.521213  0.129058  0.271736  2.85  13.647142
# 2452 2020-06-30   V  0.668385  0.519867  0.120448  0.264075  3.92  14.203947
# 2453 2020-09-30   V  0.654464  0.521290  0.107873  0.241066  4.90  14.653484
# 2454 2020-12-31   V  0.638994  0.480876  0.094422  0.201545  1.42  15.908283
# 2455 2021-03-31   V  0.640128  0.488704  0.095218  0.202568  2.80  16.088525
#
#        DPS  cur_ratio  quick_ratio  cash_ratio  inv_turnover  \
# 2451  0.30   1.248714     1.140070    0.955150           0.0
# 2452  0.30   1.553478     1.443292    1.221925           0.0
# 2453  0.30   1.905238     1.784838    1.579807           0.0
# 2454  0.32   2.121065     1.969814    1.700081           0.0
# 2455  0.32   2.116356     1.954292    1.700574           0.0
#
#       acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity
# 2451          6.116350          2.697537    0.525062        1.105537
# 2452          5.063131          1.889507    0.543886        1.192433
# 2453          5.628571          2.730366    0.552515        1.234714
# 2454          4.725314          2.347866    0.531507        1.134505
# 2455          4.844961          2.367357    0.529946        1.127414

# %%
list_ticker = df["tic"].unique().tolist()
list_date = list(pd.date_range(df['date'].min(),df['date'].max()))
combination = list(itertools.product(list_date,list_ticker))

# Merge stock price data and ratios into one dataframe
processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(df,on=["date","tic"],how="left")
processed_full = processed_full.merge(final_ratios,how='left',on=['date','tic'])
processed_full = processed_full.sort_values(['tic','date'])

# Backfill the ratio data to make them daily
processed_full = processed_full.bfill(axis='rows')

# %%
# Calculate P/E, P/B and dividend yield using daily closing price
processed_full['PE'] = processed_full['close']/processed_full['EPS']
processed_full['PB'] = processed_full['close']/processed_full['BPS']
processed_full['Div_yield'] = processed_full['DPS']/processed_full['close']

# Drop per share items used for the above calculation
processed_full = processed_full.drop(columns=['day','EPS','BPS','DPS'])
# Replace NAs infinite values with zero
processed_full = processed_full.copy()
processed_full = processed_full.fillna(0)
processed_full = processed_full.replace(np.inf,0)

# %%
# Check the final data
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#         date   tic      open      high       low     close        volume  \
# 0 2009-01-02  AAPL  3.067143  3.251429  3.041429  2.747391  7.460152e+08
# 1 2009-01-03  AAPL  3.327500  3.435000  3.311071  2.863342  1.181608e+09
# 2 2009-01-04  AAPL  3.327500  3.435000  3.311071  2.863342  1.181608e+09
# 3 2009-01-05  AAPL  3.327500  3.435000  3.311071  2.863342  1.181608e+09
# 4 2009-01-06  AAPL  3.426786  3.470357  3.299643  2.816113  1.289310e+09
# 5 2009-01-07  AAPL  3.278929  3.303571  3.223571  2.755262  7.530488e+08
# 6 2009-01-08  AAPL  3.229643  3.326786  3.215714  2.806425  6.735008e+08
# 7 2009-01-09  AAPL  3.328929  3.335000  3.219286  2.742243  5.468456e+08
# 8 2009-01-10  AAPL  3.230714  3.249643  3.126786  2.684118  6.177164e+08
# 9 2009-01-11  AAPL  3.230714  3.249643  3.126786  2.684118  6.177164e+08
#
#         OPM       NPM       ROA  ...  quick_ratio  cash_ratio  inv_turnover  \
# 0  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 1  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 2  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 3  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 4  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 5  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 6  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 7  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 8  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 9  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
#
#    acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity        PE  \
# 0          8.972003          4.269115    0.437727        0.778495  0.631584
# 1          8.972003          4.269115    0.437727        0.778495  0.658239
# 2          8.972003          4.269115    0.437727        0.778495  0.658239
# 3          8.972003          4.269115    0.437727        0.778495  0.658239
# 4          8.972003          4.269115    0.437727        0.778495  0.647382
# 5          8.972003          4.269115    0.437727        0.778495  0.633393
# 6          8.972003          4.269115    0.437727        0.778495  0.645155
# 7          8.972003          4.269115    0.437727        0.778495  0.630401
# 8          8.972003          4.269115    0.437727        0.778495  0.617039
# 9          8.972003          4.269115    0.437727        0.778495  0.617039
#
#          PB  Div_yield
# 0  0.100795        0.0
# 1  0.105049        0.0
# 2  0.105049        0.0
# 3  0.105049        0.0
# 4  0.103316        0.0
# 5  0.101084        0.0
# 6  0.102961        0.0
# 7  0.100606        0.0
# 8  0.098474        0.0
# 9  0.098474        0.0
#
# [10 rows x 22 columns]

# %%
train_data = data_split(processed_full, TRAIN_START_DATE, TRAIN_END_DATE)
trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
# Check the length of the two datasets
print(len(train_data))
print(len(trade_data))
# Out:
# 3651
# 731

# %%
train_data.head()
# Out:
#         date   tic      open      high       low     close        volume  \
# 0 2009-01-02  AAPL  3.067143  3.251429  3.041429  2.747391  7.460152e+08
# 1 2009-01-03  AAPL  3.327500  3.435000  3.311071  2.863342  1.181608e+09
# 2 2009-01-04  AAPL  3.327500  3.435000  3.311071  2.863342  1.181608e+09
# 3 2009-01-05  AAPL  3.327500  3.435000  3.311071  2.863342  1.181608e+09
# 4 2009-01-06  AAPL  3.426786  3.470357  3.299643  2.816113  1.289310e+09
#
#         OPM       NPM       ROA  ...  quick_ratio  cash_ratio  inv_turnover  \
# 0  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 1  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 2  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 3  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
# 4  0.217886  0.163846  0.103222  ...     2.039779    1.818995     54.403846
#
#    acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity        PE  \
# 0          8.972003          4.269115    0.437727        0.778495  0.631584
# 1          8.972003          4.269115    0.437727        0.778495  0.658239
# 2          8.972003          4.269115    0.437727        0.778495  0.658239
# 3          8.972003          4.269115    0.437727        0.778495  0.658239
# 4          8.972003          4.269115    0.437727        0.778495  0.647382
#
#          PB  Div_yield
# 0  0.100795        0.0
# 1  0.105049        0.0
# 2  0.105049        0.0
# 3  0.105049        0.0
# 4  0.103316        0.0
#
# [5 rows x 22 columns]

# %%
trade_data.head()
# Out:
#         date   tic       open       high        low      close       volume  \
# 0 2019-01-01  AAPL  38.722500  39.712502  38.557499  37.893330  148158800.0
# 1 2019-01-02  AAPL  38.722500  39.712502  38.557499  37.893330  148158800.0
# 2 2019-01-03  AAPL  35.994999  36.430000  35.500000  34.118877  365248800.0
# 3 2019-01-04  AAPL  36.132500  37.137501  35.950001  35.575386  234428400.0
# 4 2019-01-05  AAPL  37.174999  37.207500  36.474998  35.496208  219111200.0
#
#         OPM       NPM      ROA  ...  quick_ratio  cash_ratio  inv_turnover  \
# 0  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
# 1  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
# 2  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
# 3  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
# 4  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
#
#    acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity        PE  \
# 0          7.620024          3.781658    0.690466        2.230663  5.655721
# 1          7.620024          3.781658    0.690466        2.230663  5.655721
# 2          7.620024          3.781658    0.690466        2.230663  5.092370
# 3          7.620024          3.781658    0.690466        2.230663  5.309759
# 4          7.620024          3.781658    0.690466        2.230663  5.297942
#
#          PB  Div_yield
# 0  1.649210   0.019265
# 1  1.649210   0.019265
# 2  1.484936   0.021396
# 3  1.548327   0.020520
# 4  1.544881   0.020566
#
# [5 rows x 22 columns]

# %%
import gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gym import spaces
from gym.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv

matplotlib.use("Agg")

# from stable_baselines3.common import logger


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        turbulence_threshold=None,
        risk_indicator_col="turbulence",
        make_plots=False,
        print_verbosity=10,
        day=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="", 
    ):
        self.day = day
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        self.data = self.df.loc[self.day, :]
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        self.turbulence_threshold = turbulence_threshold
        self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        # memorize all the total balance change
        self.asset_memory = [self.initial_amount]
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        # self.reset()
        self._seed()

    def _sell_stock(self, index, action):
        def _do_sell_normal():
            if self.state[index + 1] > 0:
                # Sell only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                if self.state[index + self.stock_dim + 1] > 0:
                    # Sell only if current asset is > 0
                    sell_num_shares = min(
                        abs(action), self.state[index + self.stock_dim + 1]
                    )
                    sell_amount = (
                        self.state[index + 1]
                        * sell_num_shares
                        * (1 - self.sell_cost_pct)
                    )
                    # update balance
                    self.state[0] += sell_amount

                    self.state[index + self.stock_dim + 1] -= sell_num_shares
                    self.cost += (
                        self.state[index + 1] * sell_num_shares * self.sell_cost_pct
                    )
                    self.trades += 1
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = 0

            return sell_num_shares

        # perform sell action based on the sign of the action
        if self.turbulence_threshold is not None:
            if self.turbulence >= self.turbulence_threshold:
                if self.state[index + 1] > 0:
                    # Sell only if the price is > 0 (no missing data in this particular date)
                    # if turbulence goes over threshold, just clear out all positions
                    if self.state[index + self.stock_dim + 1] > 0:
                        # Sell only if current asset is > 0
                        sell_num_shares = self.state[index + self.stock_dim + 1]
                        sell_amount = (
                            self.state[index + 1]
                            * sell_num_shares
                            * (1 - self.sell_cost_pct)
                        )
                        # update balance
                        self.state[0] += sell_amount
                        self.state[index + self.stock_dim + 1] = 0
                        self.cost += (
                            self.state[index + 1] * sell_num_shares * self.sell_cost_pct
                        )
                        self.trades += 1
                    else:
                        sell_num_shares = 0
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = _do_sell_normal()
        else:
            sell_num_shares = _do_sell_normal()

        return sell_num_shares

    def _buy_stock(self, index, action):
        def _do_buy():
            if self.state[index + 1] > 0:
                # Buy only if the price is > 0 (no missing data in this particular date)
                available_amount = self.state[0] // self.state[index + 1]
                # print('available_amount:{}'.format(available_amount))

                # update balance
                buy_num_shares = min(available_amount, action)
                buy_amount = (
                    self.state[index + 1] * buy_num_shares * (1 + self.buy_cost_pct)
                )
                self.state[0] -= buy_amount

                self.state[index + self.stock_dim + 1] += buy_num_shares

                self.cost += self.state[index + 1] * buy_num_shares * self.buy_cost_pct
                self.trades += 1
            else:
                buy_num_shares = 0

            return buy_num_shares

        # perform buy action based on the sign of the action
        if self.turbulence_threshold is None:
            buy_num_shares = _do_buy()
        else:
            if self.turbulence < self.turbulence_threshold:
                buy_num_shares = _do_buy()
            else:
                buy_num_shares = 0
                pass

        return buy_num_shares

    def _make_plot(self):
        plt.plot(self.asset_memory, "r")
        plt.savefig("results/account_value_trade_{}.png".format(self.episode))
        plt.close()

    def step(self, actions):
        self.terminal = self.day >= len(self.df.index.unique()) - 1
        if self.terminal:
            # print(f"Episode: {self.episode}")
            if self.make_plots:
                self._make_plot()
            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            df_total_value = pd.DataFrame(self.asset_memory)
            tot_reward = (
                self.state[0]
                + sum(
                    np.array(self.state[1 : (self.stock_dim + 1)])
                    * np.array(
                        self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                    )
                )
                - self.initial_amount
            )
            df_total_value.columns = ["account_value"]
            df_total_value["date"] = self.date_memory
            df_total_value["daily_return"] = df_total_value["account_value"].pct_change(
                1
            )
            if df_total_value["daily_return"].std() != 0:
                sharpe = (
                    (252 ** 0.5)
                    * df_total_value["daily_return"].mean()
                    / df_total_value["daily_return"].std()
                )
            df_rewards = pd.DataFrame(self.rewards_memory)
            df_rewards.columns = ["account_rewards"]
            df_rewards["date"] = self.date_memory[:-1]
            if self.episode % self.print_verbosity == 0:
                print(f"day: {self.day}, episode: {self.episode}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"total_reward: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost:0.2f}")
                print(f"total_trades: {self.trades}")
                if df_total_value["daily_return"].std() != 0:
                    print(f"Sharpe: {sharpe:0.3f}")
                print("=================================")

            if (self.model_name != "") and (self.mode != ""):
                df_actions = self.save_action_memory()
                df_actions.to_csv(
                    "results/actions_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    )
                )
                df_total_value.to_csv(
                    "results/account_value_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                df_rewards.to_csv(
                    "results/account_rewards_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.plot(self.asset_memory, "r")
                plt.savefig(
                    "results/account_value_{}_{}_{}.png".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.close()

            # Add outputs to logger interface
            # logger.record("environment/portfolio_value", end_total_asset)
            # logger.record("environment/total_reward", tot_reward)
            # logger.record("environment/total_reward_pct", (tot_reward / (end_total_asset - tot_reward)) * 100)
            # logger.record("environment/total_cost", self.cost)
            # logger.record("environment/total_trades", self.trades)

            return self.state, self.reward, self.terminal, {}

        else:

            actions = actions * self.hmax  # actions initially is scaled between 0 to 1
            actions = actions.astype(
                int
            )  # convert into integer because we can't by fraction of shares
            if self.turbulence_threshold is not None:
                if self.turbulence >= self.turbulence_threshold:
                    actions = np.array([-self.hmax] * self.stock_dim)
            begin_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            # print("begin_total_asset:{}".format(begin_total_asset))

            argsort_actions = np.argsort(actions)

            sell_index = argsort_actions[: np.where(actions < 0)[0].shape[0]]
            buy_index = argsort_actions[::-1][: np.where(actions > 0)[0].shape[0]]

            for index in sell_index:
                # print(f"Num shares before: {self.state[index+self.stock_dim+1]}")
                # print(f'take sell action before : {actions[index]}')
                actions[index] = self._sell_stock(index, actions[index]) * (-1)
                # print(f'take sell action after : {actions[index]}')
                # print(f"Num shares after: {self.state[index+self.stock_dim+1]}")

            for index in buy_index:
                # print('take buy action: {}'.format(actions[index]))
                actions[index] = self._buy_stock(index, actions[index])

            self.actions_memory.append(actions)

            # state: s -> s+1
            self.day += 1
            self.data = self.df.loc[self.day, :]
            if self.turbulence_threshold is not None:
                if len(self.df.tic.unique()) == 1:
                    self.turbulence = self.data[self.risk_indicator_col]
                elif len(self.df.tic.unique()) > 1:
                    self.turbulence = self.data[self.risk_indicator_col].values[0]
            self.state = self._update_state()

            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())
            self.reward = end_total_asset - begin_total_asset
            self.rewards_memory.append(self.reward)
            self.reward = self.reward * self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        # initiate state
        self.state = self._initiate_state()

        if self.initial:
            self.asset_memory = [self.initial_amount]
        else:
            previous_total_asset = self.previous_state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(
                    self.previous_state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                )
            )
            self.asset_memory = [previous_total_asset]

        self.day = 0
        self.data = self.df.loc[self.day, :]
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.terminal = False
        # self.iteration=self.iteration
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]

        self.episode += 1

        return self.state

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        if self.initial:
            # For Initial State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.initial_amount]
                    + self.data.close.values.tolist()
                    + [0] * self.stock_dim
                    + sum(
                        [
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ],
                        [],
                    )
                )
            else:
                # for single stock
                state = (
                    [self.initial_amount]
                    + [self.data.close]
                    + [0] * self.stock_dim
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
        else:
            # Using Previous State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.previous_state[0]]
                    + self.data.close.values.tolist()
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum(
                        [
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ],
                        [],
                    )
                )
            else:
                # for single stock
                state = (
                    [self.previous_state[0]]
                    + [self.data.close]
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
        return state

    def _update_state(self):
        if len(self.df.tic.unique()) > 1:
            # for multiple stock
            state = (
                [self.state[0]]
                + self.data.close.values.tolist()
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum(
                    [
                        self.data[tech].values.tolist()
                        for tech in self.tech_indicator_list
                    ],
                    [],
                )
            )

        else:
            # for single stock
            state = (
                [self.state[0]]
                + [self.data.close]
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
            )
        return state

    def _get_date(self):
        if len(self.df.tic.unique()) > 1:
            date = self.data.date.unique()[0]
        else:
            date = self.data.date
        return date

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        # print(len(date_list))
        # print(len(asset_list))
        df_account_value = pd.DataFrame(
            {"date": date_list, "account_value": asset_list}
        )
        return df_account_value

    def save_action_memory(self):
        if len(self.df.tic.unique()) > 1:
            # date and close price length must match actions length
            date_list = self.date_memory[:-1]
            df_date = pd.DataFrame(date_list)
            df_date.columns = ["date"]

            action_list = self.actions_memory
            df_actions = pd.DataFrame(action_list)
            df_actions.columns = self.data.tic.values
            df_actions.index = df_date.date
            # df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        else:
            date_list = self.date_memory[:-1]
            action_list = self.actions_memory
            df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
import gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gym import spaces
from gym.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv

matplotlib.use("Agg")

# from stable_baselines3.common import logger


class AdversarialStockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        turbulence_threshold=None,
        risk_indicator_col="turbulence",
        make_plots=False,
        print_verbosity=10,
        day=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="", 
        adversarial_model_type='sac',
        adversarial_file_path=None,
        adversarial_gamma = 0.02
    ):
        self.day = day
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        self.data = self.df.loc[self.day, :]
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        self.turbulence_threshold = turbulence_threshold
        self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        # memorize all the total balance change
        self.asset_memory = [self.initial_amount]
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]
        # self.reset()
        self._seed()

        #load adversarial from file
        self.adversarial = MODELS[adversarial_model_type].load(adversarial_file_path)
        self.adversarial_gamma = adversarial_gamma

    def _sell_stock(self, index, action):
        def _do_sell_normal():
            if self.state[index + 1] > 0:
                # Sell only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                if self.state[index + self.stock_dim + 1] > 0:
                    # Sell only if current asset is > 0
                    sell_num_shares = min(
                        abs(action), self.state[index + self.stock_dim + 1]
                    )
                    sell_amount = (
                        self.state[index + 1]
                        * sell_num_shares
                        * (1 - self.sell_cost_pct)
                    )
                    # update balance
                    self.state[0] += sell_amount

                    self.state[index + self.stock_dim + 1] -= sell_num_shares
                    self.cost += (
                        self.state[index + 1] * sell_num_shares * self.sell_cost_pct
                    )
                    self.trades += 1
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = 0

            return sell_num_shares

        # perform sell action based on the sign of the action
        if self.turbulence_threshold is not None:
            if self.turbulence >= self.turbulence_threshold:
                if self.state[index + 1] > 0:
                    # Sell only if the price is > 0 (no missing data in this particular date)
                    # if turbulence goes over threshold, just clear out all positions
                    if self.state[index + self.stock_dim + 1] > 0:
                        # Sell only if current asset is > 0
                        sell_num_shares = self.state[index + self.stock_dim + 1]
                        sell_amount = (
                            self.state[index + 1]
                            * sell_num_shares
                            * (1 - self.sell_cost_pct)
                        )
                        # update balance
                        self.state[0] += sell_amount
                        self.state[index + self.stock_dim + 1] = 0
                        self.cost += (
                            self.state[index + 1] * sell_num_shares * self.sell_cost_pct
                        )
                        self.trades += 1
                    else:
                        sell_num_shares = 0
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = _do_sell_normal()
        else:
            sell_num_shares = _do_sell_normal()

        return sell_num_shares

    def _buy_stock(self, index, action):
        def _do_buy():
            if self.state[index + 1] > 0:
                # Buy only if the price is > 0 (no missing data in this particular date)
                available_amount = self.state[0] // self.state[index + 1]
                # print('available_amount:{}'.format(available_amount))

                # update balance
                buy_num_shares = min(available_amount, action)
                buy_amount = (
                    self.state[index + 1] * buy_num_shares * (1 + self.buy_cost_pct)
                )
                self.state[0] -= buy_amount

                self.state[index + self.stock_dim + 1] += buy_num_shares

                self.cost += self.state[index + 1] * buy_num_shares * self.buy_cost_pct
                self.trades += 1
            else:
                buy_num_shares = 0

            return buy_num_shares

        # perform buy action based on the sign of the action
        if self.turbulence_threshold is None:
            buy_num_shares = _do_buy()
        else:
            if self.turbulence < self.turbulence_threshold:
                buy_num_shares = _do_buy()
            else:
                buy_num_shares = 0
                pass

        return buy_num_shares

    def _make_plot(self):
        plt.plot(self.asset_memory, "r")
        plt.savefig("results/account_value_trade_{}.png".format(self.episode))
        plt.close()

    def step(self, actions):
        self.terminal = self.day >= len(self.df.index.unique()) - 1
        if self.terminal:
            # print(f"Episode: {self.episode}")
            if self.make_plots:
                self._make_plot()
            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            df_total_value = pd.DataFrame(self.asset_memory)
            tot_reward = (
                self.state[0]
                + sum(
                    np.array(self.state[1 : (self.stock_dim + 1)])
                    * np.array(
                        self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                    )
                )
                - self.initial_amount
            )
            df_total_value.columns = ["account_value"]
            df_total_value["date"] = self.date_memory
            df_total_value["daily_return"] = df_total_value["account_value"].pct_change(
                1
            )
            if df_total_value["daily_return"].std() != 0:
                sharpe = (
                    (252 ** 0.5)
                    * df_total_value["daily_return"].mean()
                    / df_total_value["daily_return"].std()
                )
            df_rewards = pd.DataFrame(self.rewards_memory)
            df_rewards.columns = ["account_rewards"]
            df_rewards["date"] = self.date_memory[:-1]
            if self.episode % self.print_verbosity == 0:
                print(f"day: {self.day}, episode: {self.episode}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"total_reward: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost:0.2f}")
                print(f"total_trades: {self.trades}")
                if df_total_value["daily_return"].std() != 0:
                    print("Sharpe: ", sharpe)
                print("=================================")

            if (self.model_name != "") and (self.mode != ""):
                df_actions = self.save_action_memory()
                df_actions.to_csv(
                    "results/actions_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    )
                )
                df_total_value.to_csv(
                    "results/account_value_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                df_rewards.to_csv(
                    "results/account_rewards_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.plot(self.asset_memory, "r")
                plt.savefig(
                    "results/account_value_{}_{}_{}.png".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.close()

            # Add outputs to logger interface
            # logger.record("environment/portfolio_value", end_total_asset)
            # logger.record("environment/total_reward", tot_reward)
            # logger.record("environment/total_reward_pct", (tot_reward / (end_total_asset - tot_reward)) * 100)
            # logger.record("environment/total_cost", self.cost)
            # logger.record("environment/total_trades", self.trades)

            return self.state, self.reward, self.terminal, {}

        else:

            actions = actions * self.hmax  # actions initially is scaled between 0 to 1
            actions = actions.astype(
                int
            )  # convert into integer because we can't by fraction of shares
            if self.turbulence_threshold is not None:
                if self.turbulence >= self.turbulence_threshold:
                    actions = np.array([-self.hmax] * self.stock_dim)
            begin_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            # print("begin_total_asset:{}".format(begin_total_asset))

            argsort_actions = np.argsort(actions)

            sell_index = argsort_actions[: np.where(actions < 0)[0].shape[0]]
            buy_index = argsort_actions[::-1][: np.where(actions > 0)[0].shape[0]]

            for index in sell_index:
                # print(f"Num shares before: {self.state[index+self.stock_dim+1]}")
                # print(f'take sell action before : {actions[index]}')
                actions[index] = self._sell_stock(index, actions[index]) * (-1)
                # print(f'take sell action after : {actions[index]}')
                # print(f"Num shares after: {self.state[index+self.stock_dim+1]}")

            for index in buy_index:
                # print('take buy action: {}'.format(actions[index]))
                actions[index] = self._buy_stock(index, actions[index])

            self.actions_memory.append(actions)

            # state: s -> s+1
            self.day += 1
            self.data = self.df.loc[self.day, :]
            
            ### Add adversarial
            print("self.data.close", self.data.close)
            adversarial_action = self.adversarial.predict(self.state)
            print("adversarial_action", adversarial_action[0])
            self.data.close = self.data.close * (1 + adversarial_action[0][0] * self.adversarial_gamma)
            print("self.data.close mods", self.data.close)
            if self.turbulence_threshold is not None:
                if len(self.df.tic.unique()) == 1:
                    self.turbulence = self.data[self.risk_indicator_col]
                elif len(self.df.tic.unique()) > 1:
                    self.turbulence = self.data[self.risk_indicator_col].values[0]
            self.state = self._update_state()

            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())
            self.reward = end_total_asset - begin_total_asset
            self.rewards_memory.append(self.reward)
            self.reward = self.reward * self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        # initiate state
        self.state = self._initiate_state()

        if self.initial:
            self.asset_memory = [self.initial_amount]
        else:
            previous_total_asset = self.previous_state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(
                    self.previous_state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                )
            )
            self.asset_memory = [previous_total_asset]

        self.day = 0
        self.data = self.df.loc[self.day, :]
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.terminal = False
        # self.iteration=self.iteration
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]

        self.episode += 1

        return self.state

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        if self.initial:
            # For Initial State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.initial_amount]
                    + self.data.close.values.tolist()
                    + [0] * self.stock_dim
                    + sum(
                        [
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ],
                        [],
                    )
                )
            else:
                # for single stock
                state = (
                    [self.initial_amount]
                    + [self.data.close]
                    + [0] * self.stock_dim
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
        else:
            # Using Previous State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.previous_state[0]]
                    + self.data.close.values.tolist()
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum(
                        [
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ],
                        [],
                    )
                )
            else:
                # for single stock
                state = (
                    [self.previous_state[0]]
                    + [self.data.close]
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
                )
        return state

    def _update_state(self):
        if len(self.df.tic.unique()) > 1:
            # for multiple stock
            state = (
                [self.state[0]]
                + self.data.close.values.tolist()
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum(
                    [
                        self.data[tech].values.tolist()
                        for tech in self.tech_indicator_list
                    ],
                    [],
                )
            )

        else:
            # for single stock
            state = (
                [self.state[0]]
                + [self.data.close]
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum([[self.data[tech]] for tech in self.tech_indicator_list], [])
            )
        return state

    def _get_date(self):
        if len(self.df.tic.unique()) > 1:
            date = self.data.date.unique()[0]
        else:
            date = self.data.date
        return date

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        # print(len(date_list))
        # print(len(asset_list))
        df_account_value = pd.DataFrame(
            {"date": date_list, "account_value": asset_list}
        )
        return df_account_value

    def save_action_memory(self):
        if len(self.df.tic.unique()) > 1:
            # date and close price length must match actions length
            date_list = self.date_memory[:-1]
            df_date = pd.DataFrame(date_list)
            df_date.columns = ["date"]

            action_list = self.actions_memory
            df_actions = pd.DataFrame(action_list)
            df_actions.columns = self.data.tic.values
            df_actions.index = df_date.date
            # df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        else:
            date_list = self.date_memory[:-1]
            action_list = self.actions_memory
            df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
ratio_list = ['OPM', 'NPM','ROA', 'ROE', 'cur_ratio', 'quick_ratio', 'cash_ratio', 'inv_turnover','acc_rec_turnover', 'acc_pay_turnover', 'debt_ratio', 'debt_to_equity',
       'PE', 'PB', 'Div_yield']

stock_dimension = len(train_data.tic.unique()) # Number of stocks
state_space = 1 + 2*stock_dimension + len(ratio_list)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 1, State Space: 18

# %%
# Parameters for the environment
num_stock_shares = [0] * stock_dimension
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": ratio_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
}

#Add the adversarial agent to the trading environment
e_train_gym = AdversarialStockTradingEnv(df = train_data, adversarial_file_path=f"{TRAINED_MODEL_DIR}/ppo/ppo_base_50000.zip", adversarial_model_type='ppo', **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
# Set up the agent using DRLAgent() class using the environment created in the previous part
agent = DRLAgent(env = env_train)

if_using_a2c = False
if_using_ddpg = False
if_using_ppo = True
if_using_td3 = False
if_using_sac = False

# %%
def CreateAdversarialEnv(adversarial_file_path:str, adversarial_model_type:str, adversarial_gamma: float):
    adv_train_env, _ = AdversarialStockTradingEnv(df = train_data, 
        adversarial_file_path=adversarial_file_path, 
        adversarial_model_type=adversarial_model_type, 
        adversarial_gamma = adversarial_gamma,
        **env_kwargs).get_sb_env()
    return adv_train_env
def LoadModel(model_file_path, model_type):
    if os.path.exists(model_file_path+'.zip'):
        base_model = MODELS[model_type].load(model_file_path)
        return base_model
    else: 
        raise Exception("model_file_path Invalid")

# %%
def AdversarialTraining(base_model_path, base_model_type:str, 
            adversarial_model_path, adversarial_model_type, adversarial_gamma,
            alternating_train_lapse, total_train_cycles):
        for _ in range(total_train_cycles):
            # Train the base model
            base_model = LoadModel(base_model_path, base_model_type)
            base_model.env = CreateAdversarialEnv(adversarial_model_path, adversarial_model_type, adversarial_gamma)
            agent = DRLAgent(env = base_model.env)
            base_model = agent.train_model(model=base_model, 
                                    tb_log_name='base_model_type',
                                    total_timesteps=alternating_train_lapse,
                                    )
            base_model.save(base_model_path)

            # Train the adversial
            adversarial_model = LoadModel(adversarial_model_path, adversarial_model_type)
            adversarial_model.env = CreateAdversarialEnv(base_model_path, base_model_type, adversarial_gamma)
            agent = DRLAgent(env = adversarial_model.env)
            adversarial_model = agent.train_model(model=adversarial_model, 
                                    tb_log_name='base_model_type',
                                    total_timesteps=alternating_train_lapse,
                                    )
            adversarial_model.save(adversarial_model_path)

# %% [markdown]
# ### Model 1: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/ppo/ppo_50000"
if if_using_ppo:
    if not os.path.exists(model_file_path+'.zip'):
        trained_ppo = agent.train_model(model=model_ppo, 
                                    tb_log_name='ppo',
                                    total_timesteps=50000,
                                    ) 
        trained_ppo.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_ppo = MODELS['ppo'].load(model_file_path)
        trained_ppo.env = env_train
        print("agent loaded from", model_file_path)


# AdversarialTraining(base_model_path=f"{TRAINED_MODEL_DIR}/ppo/ppo_base_50000", base_model_type='ppo', 
#             adversarial_model_path=f"{TRAINED_MODEL_DIR}/ppo/ppo_adv_50000", adversarial_model_type='ppo', adversarial_gamma=0.02,
#             alternating_train_lapse=3000, total_train_cycles=1)
# trained_ppo = LoadModel(f"{TRAINED_MODEL_DIR}/ppo/ppo_base_50000", 'ppo')

AdversarialTraining(base_model_path=f"{TRAINED_MODEL_DIR}/ppo/ppo_base_50000", base_model_type='ppo', 
            adversarial_model_path=f"{TRAINED_MODEL_DIR}/sac/sac_adv_40000", adversarial_model_type='sac', adversarial_gamma=0.03,
            alternating_train_lapse=3000, total_train_cycles=1)
trained_ppo = LoadModel(f"{TRAINED_MODEL_DIR}/ppo/ppo_base_50000", 'ppo')
# Out:
# agent loaded from trained_models/ppo/ppo_50000
# self.data.close 2.863341808319092
# adversarial_action [1.]
# self.data.close mods 2.949242062568665
# self.data.close 2.863341808319092
# adversarial_action [1.]
# self.data.close mods 2.949242062568665
# self.data.close 2.863341808319092
# adversarial_action [1.]
# self.data.close mods 2.949242062568665
# self.data.close 2.816113233566284
# adversarial_action [1.]
# self.data.close mods 2.900596630573273
# self.data.close 2.7552616596221924
# adversarial_action [1.]
# self.data.close mods 2.8379195094108582
# self.data.close 2.8064253330230713
# adversarial_action [1.]
# self.data.close mods 2.8906180930137637
# self.data.close 2.7422432899475098
# adversarial_action [1.]
# self.data.close mods 2.824510588645935
# self.data.close 2.6841177940368652
# adversarial_action [1.]
# self.data.close mods 2.764641327857971
# self.data.close 2.6841177940368652
# adversarial_action [1.]
# self.data.close mods 2.764641327857971
# self.data.close 2.6841177940368652
# adversarial_action [1.]
# self.data.close mods 2.764641327857971
# self.data.close 2.655357599258423
# adversarial_action [1.]
# self.data.close mods 2.7350183272361757
# self.data.close 2.583303928375244
# adversarial_action [1.]
# self.data.close mods 2.6608030462265013
# self.data.close 2.524268865585327
# adversarial_action [1.]
# self.data.close mods 2.5999969315528872
# self.data.close 2.4924814701080322
# adversarial_action [1.]
# self.data.close mods 2.567255914211273
# self.data.close 2.367448091506958
# adversarial_action [1.]
# self.data.close mods 2.438471534252167
# self.data.close 2.367448091506958
# adversarial_action [1.]
# self.data.close mods 2.438471534252167
# self.data.close 2.367448091506958
# adversarial_action [1.]
# self.data.close mods 2.438471534252167
# self.data.close 2.367448091506958
# adversarial_action [1.]
# self.data.close mods 2.438471534252167
# self.data.close 2.5076184272766113
# adversarial_action [1.]
# self.data.close mods 2.5828469800949097
# self.data.close 2.675034761428833
# adversarial_action [1.]
# self.data.close mods 2.755285804271698
# self.data.close 2.675034761428833
# adversarial_action [1.]
# self.data.close mods 2.755285804271698
# self.data.close 2.7137858867645264
# adversarial_action [1.]
# self.data.close mods 2.7951994633674624
# self.data.close 2.7137858867645264
# adversarial_action [1.]
# self.data.close mods 2.7951994633674624
# self.data.close 2.7137858867645264
# adversarial_action [1.]
# self.data.close mods 2.7951994633674624
# self.data.close 2.7467851638793945
# adversarial_action [1.]
# self.data.close mods 2.8291887187957765
# self.data.close 2.851837158203125
# adversarial_action [1.]
# self.data.close mods 2.937392272949219
# self.data.close 2.815507650375366
# adversarial_action [1.]
# self.data.close mods 2.899972879886627
# self.data.close 2.7286202907562256
# adversarial_action [1.]
# self.data.close mods 2.8104788994789125
# self.data.close 2.7703986167907715
# adversarial_action [1.]
# self.data.close mods 2.8535105752944947
# self.data.close 2.7703986167907715
# adversarial_action [1.]
# self.data.close mods 2.8535105752944947
# self.data.close 2.7703986167907715
# adversarial_action [1.]
# self.data.close mods 2.8535105752944947
# self.data.close 2.8149023056030273
# adversarial_action [1.]
# self.data.close mods 2.899349374771118
# self.data.close 2.832157850265503
# adversarial_action [1.]
# self.data.close mods 2.917122585773468
# self.data.close 2.9202563762664795
# adversarial_action [1.]
# self.data.close mods 3.007864067554474
# self.data.close 3.018951416015625
# adversarial_action [1.]
# self.data.close mods 3.1095199584960938
# self.data.close 3.1034154891967773
# adversarial_action [1.]
# self.data.close mods 3.196517953872681
# self.data.close 3.1034154891967773
# adversarial_action [1.]
# self.data.close mods 3.196517953872681
# self.data.close 3.1034154891967773
# adversarial_action [1.]
# self.data.close mods 3.196517953872681
# self.data.close 2.9617326259613037
# adversarial_action [1.]
# self.data.close mods 3.050584604740143
# self.data.close 2.931155204772949
# adversarial_action [1.]
# self.data.close mods 3.0190898609161376
# self.data.close 3.0053272247314453
# adversarial_action [1.]
# self.data.close mods 3.0954870414733886
# self.data.close 3.001997709274292
# adversarial_action [1.]
# self.data.close mods 3.092057640552521
# self.data.close 2.8618271350860596
# adversarial_action [1.]
# self.data.close mods 2.9476819491386412
# self.data.close 2.8618271350860596
# adversarial_action [1.]
# self.data.close mods 2.9476819491386412
# self.data.close 2.8618271350860596
# adversarial_action [1.]
# self.data.close mods 2.9476819491386412
# self.data.close 2.8618271350860596
# adversarial_action [1.]
# self.data.close mods 2.9476819491386412
# self.data.close 2.856982946395874
# adversarial_action [1.]
# self.data.close mods 2.9426924347877503
# self.data.close 2.7440602779388428
# adversarial_action [1.]
# self.data.close mods 2.826382086277008
# self.data.close 2.761014223098755
# adversarial_action [1.]
# self.data.close mods 2.8438446497917176
# self.data.close 2.6323487758636475
# adversarial_action [1.]
# self.data.close mods 2.711319239139557
# self.data.close 2.6323487758636475
# adversarial_action [1.]
# self.data.close mods 2.711319239139557
# self.data.close 2.6323487758636475
# adversarial_action [1.]
# self.data.close mods 2.711319239139557
# self.data.close 2.732253313064575
# adversarial_action [1.]
# self.data.close mods 2.8142209124565127
# self.data.close 2.7598025798797607
# adversarial_action [1.]
# self.data.close mods 2.842596657276154
# self.data.close 2.7001631259918213
# adversarial_action [1.]
# self.data.close mods 2.781168019771576
# self.data.close 2.7037954330444336
# adversarial_action [1.]
# self.data.close mods 2.784909296035767
# self.data.close 2.6623196601867676
# adversarial_action [1.]
# self.data.close mods 2.7421892499923706
# self.data.close 2.6623196601867676
# adversarial_action [1.]
# self.data.close mods 2.7421892499923706
# self.data.close 2.6623196601867676
# adversarial_action [1.]
# self.data.close mods 2.7421892499923706
# self.data.close 2.675337553024292
# adversarial_action [1.]
# self.data.close mods 2.755597679615021
# self.data.close 2.760105609893799
# adversarial_action [1.]
# self.data.close mods 2.842908778190613
# self.data.close 2.689566135406494
# adversarial_action [1.]
# self.data.close mods 2.770253119468689
# self.data.close 2.582395553588867
# adversarial_action [1.]
# self.data.close mods 2.6598674201965333
# self.data.close 2.516094207763672
# adversarial_action [1.]
# self.data.close mods 2.591577033996582
# self.data.close 2.516094207763672
# adversarial_action [1.]
# self.data.close mods 2.591577033996582
# self.data.close 2.516094207763672
# adversarial_action [1.]
# self.data.close mods 2.591577033996582
# self.data.close 2.68320894241333
# adversarial_action [1.]
# self.data.close mods 2.76370521068573
# self.data.close 2.8058204650878906
# adversarial_action [1.]
# self.data.close mods 2.8899950790405273
# self.data.close 2.916926145553589
# adversarial_action [1.]
# self.data.close mods 3.0044339299201965
# self.data.close 2.9042108058929443
# adversarial_action [1.]
# self.data.close mods 2.991337130069733
# self.data.close 2.8887712955474854
# adversarial_action [1.]
# self.data.close mods 2.97543443441391
# self.data.close 2.8887712955474854
# adversarial_action [1.]
# self.data.close mods 2.97543443441391
# self.data.close 2.8887712955474854
# adversarial_action [1.]
# self.data.close mods 2.97543443441391
# self.data.close 3.017134666442871
# adversarial_action [1.]
# self.data.close mods 3.1076487064361573
# self.data.close 3.073444366455078
# adversarial_action [1.]
# self.data.close mods 3.1656476974487306
# self.data.close 3.0764718055725098
# adversarial_action [1.]
# self.data.close mods 3.168765959739685
# self.data.close 3.075563669204712
# adversarial_action [1.]
# self.data.close mods 3.1678305792808534
# self.data.close 3.259328842163086
# adversarial_action [1.]
# self.data.close mods 3.3571087074279786
# self.data.close 3.259328842163086
# adversarial_action [1.]
# self.data.close mods 3.3571087074279786
# self.data.close 3.259328842163086
# adversarial_action [1.]
# self.data.close mods 3.3571087074279786
# self.data.close 3.2242095470428467
# adversarial_action [1.]
# self.data.close mods 3.3209358334541323
# self.data.close 3.223907709121704
# adversarial_action [1.]
# self.data.close mods 3.3206249403953554
# self.data.close 3.326235294342041
# adversarial_action [1.]
# self.data.close mods 3.426022353172302
# self.data.close 3.2348062992095947
# adversarial_action [1.]
# self.data.close mods 3.3318504881858826
# self.data.close 3.1633591651916504
# adversarial_action [1.]
# self.data.close mods 3.2582599401474
# self.data.close 3.1633591651916504
# adversarial_action [1.]
# self.data.close mods 3.2582599401474
# self.data.close 3.1633591651916504
# adversarial_action [1.]
# self.data.close mods 3.2582599401474
# self.data.close 3.182431697845459
# adversarial_action [1.]
# self.data.close mods 3.2779046487808228
# self.data.close 3.2905113697052
# adversarial_action [1.]
# self.data.close mods 3.3892267107963563
# self.data.close 3.412213087081909
# adversarial_action [1.]
# self.data.close mods 3.5145794796943663
# self.data.close 3.5115139484405518
# adversarial_action [1.]
# self.data.close mods 3.6168593668937685
# self.data.close 3.585988759994507
# adversarial_action [1.]
# self.data.close mods 3.693568422794342
# self.data.close 3.585988759994507
# adversarial_action [1.]
# self.data.close mods 3.693568422794342
# self.data.close 3.585988759994507
# adversarial_action [1.]
# self.data.close mods 3.693568422794342
# self.data.close 3.481541395187378
# adversarial_action [1.]
# self.data.close mods 3.5859876370429995
# self.data.close 3.5215044021606445
# adversarial_action [1.]
# self.data.close mods 3.627149534225464
# self.data.close 3.619896411895752
# adversarial_action [1.]
# self.data.close mods 3.7284933042526247
# self.data.close 3.639573097229004
# adversarial_action [1.]
# self.data.close mods 3.7487602901458743
# self.data.close 3.639573097229004
# adversarial_action [1.]
# self.data.close mods 3.7487602901458743
# self.data.close 3.639573097229004
# adversarial_action [1.]
# self.data.close mods 3.7487602901458743
# self.data.close 3.639573097229004
# adversarial_action [1.]
# self.data.close mods 3.7487602901458743
# self.data.close 3.5817487239837646
# adversarial_action [1.]
# self.data.close mods 3.689201185703278
# self.data.close 3.561466693878174
# adversarial_action [1.]
# self.data.close mods 3.668310694694519
# self.data.close 3.6768112182617188
# adversarial_action [1.]
# self.data.close mods 3.7871155548095703
# self.data.close 3.736452102661133
# adversarial_action [1.]
# self.data.close mods 3.848545665740967
# self.data.close 3.648049831390381
# adversarial_action [1.]
# self.data.close mods 3.7574913263320924
# self.data.close 3.648049831390381
# adversarial_action [1.]
# self.data.close mods 3.7574913263320924
# self.data.close 3.648049831390381
# adversarial_action [1.]
# self.data.close mods 3.7574913263320924
# self.data.close 3.6861956119537354
# adversarial_action [1.]
# self.data.close mods 3.7967814803123474
# self.data.close 3.6786274909973145
# adversarial_action [1.]
# self.data.close mods 3.788986315727234
# self.data.close 3.796394109725952
# adversarial_action [1.]
# self.data.close mods 3.9102859330177306
# self.data.close 3.7509851455688477
# adversarial_action [1.]
# self.data.close mods 3.863514699935913
# self.data.close 3.7761101722717285
# adversarial_action [1.]
# self.data.close mods 3.8893934774398806
# self.data.close 3.7761101722717285
# adversarial_action [1.]
# self.data.close mods 3.8893934774398806
# self.data.close 3.7761101722717285
# adversarial_action [1.]
# self.data.close mods 3.8893934774398806
# self.data.close 3.7509851455688477
# adversarial_action [1.]
# self.data.close mods 3.863514699935913
# self.data.close 3.788522481918335
# adversarial_action [1.]
# self.data.close mods 3.9021781563758853
# self.data.close 3.8094124794006348
# adversarial_action [1.]
# self.data.close mods 3.9236948537826537
# self.data.close 3.8520991802215576
# adversarial_action [1.]
# self.data.close mods 3.9676621556282043
# self.data.close 3.998323678970337
# adversarial_action [1.]
# self.data.close mods 4.118273389339447
# self.data.close 3.998323678970337
# adversarial_action [1.]
# self.data.close mods 4.118273389339447
# self.data.close 3.998323678970337
# adversarial_action [1.]
# self.data.close mods 4.118273389339447
# self.data.close 4.017700672149658
# adversarial_action [1.]
# self.data.close mods 4.1382316923141484
# self.data.close 4.011343002319336
# adversarial_action [1.]
# self.data.close mods 4.131683292388916
# self.data.close 3.9071991443634033
# adversarial_action [1.]
# self.data.close mods 4.024415118694305
# self.data.close 3.911135673522949
# adversarial_action [1.]
# self.data.close mods 4.028469743728638
# self.data.close 3.9226365089416504
# adversarial_action [1.]
# self.data.close mods 4.0403156042099
# self.data.close 3.9226365089416504
# adversarial_action [1.]
# self.data.close mods 4.0403156042099
# self.data.close 3.9226365089416504
# adversarial_action [1.]
# self.data.close mods 4.0403156042099
# self.data.close 3.7667253017425537
# adversarial_action [1.]
# self.data.close mods 3.8797270607948304
# self.data.close 3.6174726486206055
# adversarial_action [1.]
# self.data.close mods 3.7259968280792237
# self.data.close 3.722221612930298
# adversarial_action [1.]
# self.data.close mods 3.833888261318207
# self.data.close 3.7061777114868164
# adversarial_action [1.]
# self.data.close mods 3.817363042831421
# self.data.close 3.834237575531006
# adversarial_action [1.]
# self.data.close mods 3.949264702796936
# self.data.close 3.834237575531006
# adversarial_action [1.]
# self.data.close mods 3.949264702796936
# self.data.close 3.834237575531006
# adversarial_action [1.]
# self.data.close mods 3.949264702796936
# self.data.close 3.8584563732147217
# adversarial_action [1.]
# self.data.close mods 3.9742100644111633
# self.data.close 3.810622453689575
# adversarial_action [1.]
# self.data.close mods 3.9249411273002623
# self.data.close 3.7594590187072754
# adversarial_action [1.]
# self.data.close mods 3.8722427892684936
# self.data.close 3.7085986137390137
# adversarial_action [1.]
# self.data.close mods 3.8198565721511843
# self.data.close 3.959270477294922
# adversarial_action [1.]
# self.data.close mods 4.078048591613769
# self.data.close 3.959270477294922
# adversarial_action [1.]
# self.data.close mods 4.078048591613769
# self.data.close 3.959270477294922
# adversarial_action [1.]
# self.data.close mods 4.078048591613769
# self.data.close 3.959270477294922
# adversarial_action [1.]
# self.data.close mods 4.078048591613769
# self.data.close 4.027993202209473
# adversarial_action [1.]
# self.data.close mods 4.148832998275757
# self.data.close 4.089146614074707
# adversarial_action [1.]
# self.data.close mods 4.211821012496948
# self.data.close 4.111548900604248
# adversarial_action [1.]
# self.data.close mods 4.234895367622376
# self.data.close 4.218719959259033
# adversarial_action [1.]
# self.data.close mods 4.345281558036804
# self.data.close 4.218719959259033
# adversarial_action [1.]
# self.data.close mods 4.345281558036804
# self.data.close 4.218719959259033
# adversarial_action [1.]
# self.data.close mods 4.345281558036804
# self.data.close 4.222959518432617
# adversarial_action [1.]
# self.data.close mods 4.349648303985596
# self.data.close 4.267160892486572
# adversarial_action [1.]
# self.data.close mods 4.39517571926117
# self.data.close 4.35162353515625
# adversarial_action [1.]
# self.data.close mods 4.482172241210938
# self.data.close 4.379780292510986
# adversarial_action [1.]
# self.data.close mods 4.5111737012863165
# self.data.close 4.354953765869141
# adversarial_action [1.]
# self.data.close mods 4.485602378845215
# self.data.close 4.354953765869141
# adversarial_action [1.]
# self.data.close mods 4.485602378845215
# self.data.close 4.354953765869141
# adversarial_action [1.]
# self.data.close mods 4.485602378845215
# self.data.close 4.32074499130249
# adversarial_action [1.]
# self.data.close mods 4.450367341041565
# self.data.close 4.245968341827393
# adversarial_action [1.]
# self.data.close mods 4.373347392082215
# self.data.close 4.236884117126465
# adversarial_action [1.]
# self.data.close mods 4.363990640640259
# self.data.close 4.146668910980225
# adversarial_action [1.]
# self.data.close mods 4.271068978309631
# self.data.close 4.120025634765625
# adversarial_action [1.]
# self.data.close mods 4.243626403808594
# self.data.close 4.120025634765625
# adversarial_action [1.]
# self.data.close mods 4.243626403808594
# self.data.close 4.120025634765625
# adversarial_action [1.]
# self.data.close mods 4.243626403808594
# self.data.close 4.127896785736084
# adversarial_action [1.]
# self.data.close mods 4.251733689308167
# self.data.close 4.104586601257324
# adversarial_action [1.]
# self.data.close mods 4.227724199295044
# self.data.close 4.113669395446777
# adversarial_action [1.]
# self.data.close mods 4.237079477310181
# self.data.close 4.222657203674316
# adversarial_action [1.]
# self.data.close mods 4.349336919784546
# self.data.close 4.158779621124268
# adversarial_action [1.]
# self.data.close mods 4.283543009757996
# self.data.close 4.158779621124268
# adversarial_action [1.]
# self.data.close mods 4.283543009757996
# self.data.close 4.158779621124268
# adversarial_action [1.]
# self.data.close mods 4.283543009757996
# self.data.close 4.0570549964904785
# adversarial_action [1.]
# self.data.close mods 4.178766646385193
# self.data.close 4.123962879180908
# adversarial_action [1.]
# self.data.close mods 4.247681765556336
# self.data.close 4.234160423278809
# adversarial_action [1.]
# self.data.close mods 4.361185235977173
# self.data.close 4.312269687652588
# adversarial_action [1.]
# self.data.close mods 4.441637778282166
# self.data.close 4.298037528991699
# adversarial_action [1.]
# self.data.close mods 4.4269786548614505
# self.data.close 4.298037528991699
# adversarial_action [1.]
# self.data.close mods 4.4269786548614505
# self.data.close 4.298037528991699
# adversarial_action [1.]
# self.data.close mods 4.4269786548614505
# self.data.close 4.3119659423828125
# adversarial_action [1.]
# self.data.close mods 4.441324920654297
# self.data.close 4.324075698852539
# adversarial_action [1.]
# self.data.close mods 4.453797969818115
# self.data.close 4.239002704620361
# adversarial_action [1.]
# self.data.close mods 4.366172785758972
# self.data.close 4.196316719055176
# adversarial_action [1.]
# self.data.close mods 4.322206220626831
# self.data.close 4.196316719055176
# adversarial_action [1.]
# self.data.close mods 4.322206220626831
# self.data.close 4.196316719055176
# adversarial_action [1.]
# self.data.close mods 4.322206220626831
# self.data.close 4.196316719055176
# adversarial_action [1.]
# self.data.close mods 4.322206220626831
# self.data.close 4.099138259887695
# adversarial_action [1.]
# self.data.close mods 4.222112407684326
# self.data.close 4.154235363006592
# adversarial_action [1.]
# self.data.close mods 4.27886242389679
# self.data.close 4.128200531005859
# adversarial_action [1.]
# self.data.close mods 4.252046546936035
# self.data.close 4.193592071533203
# adversarial_action [1.]
# self.data.close mods 4.319399833679199
# self.data.close 4.309242248535156
# adversarial_action [1.]
# self.data.close mods 4.438519515991211
# self.data.close 4.309242248535156
# adversarial_action [1.]
# self.data.close mods 4.438519515991211
# self.data.close 4.309242248535156
# adversarial_action [1.]
# self.data.close mods 4.438519515991211
# self.data.close 4.307119369506836
# adversarial_action [1.]
# self.data.close mods 4.436332950592041
# self.data.close 4.446686744689941
# adversarial_action [1.]
# self.data.close mods 4.58008734703064
# self.data.close 4.466060161590576
# adversarial_action [1.]
# self.data.close mods 4.600041966438294
# self.data.close 4.594121932983398
# adversarial_action [1.]
# self.data.close mods 4.7319455909729005
# self.data.close 4.629240036010742
# adversarial_action [1.]
# self.data.close mods 4.768117237091064
# self.data.close 4.629240036010742
# adversarial_action [1.]
# self.data.close mods 4.768117237091064
# self.data.close 4.629240036010742
# adversarial_action [1.]
# self.data.close mods 4.768117237091064
# self.data.close 4.586854934692383
# adversarial_action [1.]
# self.data.close mods 4.724460582733155
# self.data.close 4.7451887130737305
# adversarial_action [1.]
# self.data.close mods 4.887544374465943
# self.data.close 4.777885437011719
# adversarial_action [1.]
# self.data.close mods 4.921222000122071
# self.data.close 4.843581199645996
# adversarial_action [1.]
# self.data.close mods 4.9888886356353765
# self.data.close 4.846911907196045
# adversarial_action [1.]
# self.data.close mods 4.992319264411926
# self.data.close 4.846911907196045
# adversarial_action [1.]
# self.data.close mods 4.992319264411926
# self.data.close 4.846911907196045
# adversarial_action [1.]
# self.data.close mods 4.992319264411926
# self.data.close 4.843883991241455
# adversarial_action [1.]
# self.data.close mods 4.989200510978699
# self.data.close 4.84479284286499
# adversarial_action [1.]
# self.data.close mods 4.99013662815094
# self.data.close 4.928349494934082
# adversarial_action [1.]
# self.data.close mods 5.076199979782104
# self.data.close 4.9465155601501465
# adversarial_action [1.]
# self.data.close mods 5.094911026954651
# self.data.close 5.038549900054932
# adversarial_action [1.]
# self.data.close mods 5.18970639705658
# self.data.close 5.038549900054932
# adversarial_action [1.]
# self.data.close mods 5.18970639705658
# self.data.close 5.038549900054932
# adversarial_action [1.]
# self.data.close mods 5.18970639705658
# self.data.close 5.011908054351807
# adversarial_action [1.]
# self.data.close mods 5.162265295982361
# self.data.close 4.998586177825928
# adversarial_action [1.]
# self.data.close mods 5.148543763160705
# self.data.close 4.962257385253906
# adversarial_action [1.]
# self.data.close mods 5.1111251068115235
# self.data.close 5.0106964111328125
# adversarial_action [1.]
# self.data.close mods 5.161017303466797
# self.data.close 4.986778259277344
# adversarial_action [1.]
# self.data.close mods 5.1363816070556645
# self.data.close 4.986778259277344
# adversarial_action [1.]
# self.data.close mods 5.1363816070556645
# self.data.close 4.986778259277344
# adversarial_action [1.]
# self.data.close mods 5.1363816070556645
# self.data.close 4.929560661315918
# adversarial_action [1.]
# self.data.close mods 5.077447481155396
# self.data.close 5.004642009735107
# adversarial_action [1.]
# self.data.close mods 5.1547812700271605
# self.data.close 5.098793983459473
# adversarial_action [1.]
# self.data.close mods 5.251757802963257
# self.data.close 5.049144268035889
# adversarial_action [1.]
# self.data.close mods 5.200618596076965
# self.data.close 4.831471920013428
# adversarial_action [1.]
# self.data.close mods 4.97641607761383
# self.data.close 4.831471920013428
# adversarial_action [1.]
# self.data.close mods 4.97641607761383
# self.data.close 4.831471920013428
# adversarial_action [1.]
# self.data.close mods 4.97641607761383
# self.data.close 4.964982509613037
# adversarial_action [1.]
# self.data.close mods 5.113931984901428
# self.data.close 4.983145713806152
# adversarial_action [1.]
# self.data.close mods 5.132640085220337
# self.data.close 5.035518646240234
# adversarial_action [1.]
# self.data.close mods 5.186584205627441
# self.data.close 5.123012542724609
# adversarial_action [1.]
# self.data.close mods 5.276702919006348
# self.data.close 5.118168830871582
# adversarial_action [1.]
# self.data.close mods 5.271713895797729
# self.data.close 5.118168830871582
# adversarial_action [1.]
# self.data.close mods 5.271713895797729
# self.data.close 5.118168830871582
# adversarial_action [1.]
# self.data.close mods 5.271713895797729
# self.data.close 5.128461837768555
# adversarial_action [1.]
# self.data.close mods 5.282315692901611
# self.data.close 5.0682172775268555
# adversarial_action [1.]
# self.data.close mods 5.220263795852661
# self.data.close 5.12997579574585
# adversarial_action [1.]
# self.data.close mods 5.283875069618225
# self.data.close 5.148139953613281
# adversarial_action [1.]
# self.data.close mods 5.30258415222168
# self.data.close 5.092436790466309
# adversarial_action [1.]
# self.data.close mods 5.245209894180298
# self.data.close 5.092436790466309
# adversarial_action [1.]
# self.data.close mods 5.245209894180298
# self.data.close 5.092436790466309
# adversarial_action [1.]
# self.data.close mods 5.245209894180298
# self.data.close 5.004339218139648
# adversarial_action [1.]
# self.data.close mods 5.154469394683838
# self.data.close 5.000705718994141
# adversarial_action [1.]
# self.data.close mods 5.150726890563965
# self.data.close 5.042182922363281
# adversarial_action [1.]
# self.data.close mods 5.19344841003418
# self.data.close 5.15601110458374
# adversarial_action [1.]
# self.data.close mods 5.310691437721252
# self.data.close 5.235332012176514
# adversarial_action [1.]
# self.data.close mods 5.392391972541809
# self.data.close 5.235332012176514
# adversarial_action [1.]
# self.data.close mods 5.392391972541809
# self.data.close 5.235332012176514
# adversarial_action [1.]
# self.data.close mods 5.392391972541809
# self.data.close 5.235332012176514
# adversarial_action [1.]
# self.data.close mods 5.392391972541809
# self.data.close 5.181139945983887
# adversarial_action [1.]
# self.data.close mods 5.336574144363404
# self.data.close 5.224128246307373
# adversarial_action [1.]
# self.data.close mods 5.3808520936965945
# self.data.close 5.212018013000488
# adversarial_action [1.]
# self.data.close mods 5.368378553390503
# self.data.close 5.259247303009033
# adversarial_action [1.]
# self.data.close mods 5.417024722099304
# self.data.close 5.259247303009033
# adversarial_action [1.]
# self.data.close mods 5.417024722099304
# self.data.close 5.259247303009033
# adversarial_action [1.]
# self.data.close mods 5.417024722099304
# self.data.close 5.302842140197754
# adversarial_action [1.]
# self.data.close mods 5.461927404403687
# self.data.close 5.505983352661133
# adversarial_action [1.]
# self.data.close mods 5.671162853240967
# self.data.close 5.587116241455078
# adversarial_action [1.]
# self.data.close mods 5.754729728698731
# self.data.close 5.601347923278809
# adversarial_action [1.]
# self.data.close mods 5.769388360977173
# self.data.close 5.571072101593018
# adversarial_action [1.]
# self.data.close mods 5.7382042646408085
# self.data.close 5.571072101593018
# adversarial_action [1.]
# self.data.close mods 5.7382042646408085
# self.data.close 5.571072101593018
# adversarial_action [1.]
# self.data.close mods 5.7382042646408085
# self.data.close 5.584998607635498
# adversarial_action [1.]
# self.data.close mods 5.752548565864563
# self.data.close 5.615877151489258
# adversarial_action [1.]
# self.data.close mods 5.784353466033935
# self.data.close 5.565018177032471
# adversarial_action [1.]
# self.data.close mods 5.731968722343445
# self.data.close 5.521119117736816
# adversarial_action [1.]
# self.data.close mods 5.6867526912689215
# self.data.close 5.635556221008301
# adversarial_action [1.]
# self.data.close mods 5.80462290763855
# self.data.close 5.635556221008301
# adversarial_action [1.]
# self.data.close mods 5.80462290763855
# self.data.close 5.635556221008301
# adversarial_action [1.]
# self.data.close mods 5.80462290763855
# self.data.close 5.612244606018066
# adversarial_action [1.]
# self.data.close mods 5.780611944198609
# self.data.close 5.611335277557373
# adversarial_action [1.]
# self.data.close mods 5.779675335884094
# self.data.close 5.475406646728516
# adversarial_action [1.]
# self.data.close mods 5.6396688461303714
# self.data.close 5.597713947296143
# adversarial_action [1.]
# self.data.close mods 5.765645365715027
# self.data.close 5.631619930267334
# adversarial_action [1.]
# self.data.close mods 5.800568528175354
# self.data.close 5.631619930267334
# adversarial_action [1.]
# self.data.close mods 5.800568528175354
# self.data.close 5.631619930267334
# adversarial_action [1.]
# self.data.close mods 5.800568528175354
# self.data.close 5.752414703369141
# adversarial_action [1.]
# self.data.close mods 5.924987144470215
# self.data.close 5.759679794311523
# adversarial_action [1.]
# self.data.close mods 5.9324701881408695
# self.data.close 5.730014324188232
# adversarial_action [1.]
# self.data.close mods 5.901914753913879
# self.data.close 5.766343116760254
# adversarial_action [1.]
# self.data.close mods 5.939333410263061
# self.data.close 5.776634693145752
# adversarial_action [1.]
# self.data.close mods 5.949933733940124
# self.data.close 5.776634693145752
# adversarial_action [1.]
# self.data.close mods 5.949933733940124
# self.data.close 5.776634693145752
# adversarial_action [1.]
# self.data.close mods 5.949933733940124
# self.data.close 5.752719402313232
# adversarial_action [1.]
# self.data.close mods 5.92530098438263
# self.data.close 5.791168212890625
# adversarial_action [1.]
# self.data.close mods 5.964903259277344
# self.data.close 5.769066333770752
# adversarial_action [1.]
# self.data.close mods 5.942138323783874
# self.data.close 5.693077087402344
# adversarial_action [1.]
# self.data.close mods 5.863869400024414
# self.data.close 5.7478742599487305
# adversarial_action [1.]
# self.data.close mods 5.920310487747193
# self.data.close 5.7478742599487305
# adversarial_action [1.]
# self.data.close mods 5.920310487747193
# self.data.close 5.7478742599487305
# adversarial_action [1.]
# self.data.close mods 5.920310487747193
# self.data.close 6.0173139572143555
# adversarial_action [1.]
# self.data.close mods 6.197833375930786
# self.data.close 6.203805446624756
# adversarial_action [1.]
# self.data.close mods 6.389919610023498
# self.data.close 6.212281703948975
# adversarial_action [1.]
# self.data.close mods 6.398650155067444
# self.data.close 6.174135684967041
# adversarial_action [1.]
# self.data.close mods 6.359359755516053
# self.data.close 6.129935264587402
# adversarial_action [1.]
# self.data.close mods 6.313833322525024
# self.data.close 6.129935264587402
# adversarial_action [1.]
# self.data.close mods 6.313833322525024
# self.data.close 6.129935264587402
# adversarial_action [1.]
# self.data.close mods 6.313833322525024
# self.data.close 5.9752349853515625
# adversarial_action [1.]
# self.data.close mods 6.15449203491211
# self.data.close 5.824770450592041
# adversarial_action [1.]
# self.data.close mods 5.999513564109803
# self.data.close 5.9443535804748535
# adversarial_action [1.]
# self.data.close mods 6.122684187889099
# self.data.close 5.706700801849365
# adversarial_action [1.]
# self.data.close mods 5.877901825904846
# self.data.close 5.731222152709961
# adversarial_action [1.]
# self.data.close mods 5.90315881729126
# self.data.close 5.731222152709961
# adversarial_action [1.]
# self.data.close mods 5.90315881729126
# self.data.close 5.731222152709961
# adversarial_action [1.]
# self.data.close mods 5.90315881729126
# self.data.close 5.714269638061523
# adversarial_action [1.]
# self.data.close mods 5.885697727203369
# self.data.close 5.776634693145752
# adversarial_action [1.]
# self.data.close mods 5.949933733940124
# self.data.close 5.874117851257324
# adversarial_action [1.]
# self.data.close mods 6.050341386795044
# self.data.close 5.883502960205078
# adversarial_action [1.]
# self.data.close mods 6.0600080490112305
# self.data.close 6.099055767059326
# adversarial_action [1.]
# self.data.close mods 6.282027440071106
# self.data.close 6.099055767059326
# adversarial_action [1.]
# self.data.close mods 6.282027440071106
# self.data.close 6.099055767059326
# adversarial_action [1.]
# self.data.close mods 6.282027440071106
# self.data.close 6.145073413848877
# adversarial_action [1.]
# self.data.close mods 6.329425616264343
# self.data.close 6.153247356414795
# adversarial_action [1.]
# self.data.close mods 6.337844777107239
# self.data.close 6.115101337432861
# adversarial_action [1.]
# self.data.close mods 6.298554377555847
# self.data.close 6.189576148986816
# adversarial_action [1.]
# self.data.close mods 6.375263433456421
# self.data.close 6.255573749542236
# adversarial_action [1.]
# self.data.close mods 6.443240962028503
# self.data.close 6.255573749542236
# adversarial_action [1.]
# self.data.close mods 6.443240962028503
# self.data.close 6.255573749542236
# adversarial_action [1.]
# self.data.close mods 6.443240962028503
# self.data.close 6.2667765617370605
# adversarial_action [1.]
# self.data.close mods 6.4547798585891725
# self.data.close 6.235288619995117
# adversarial_action [1.]
# self.data.close mods 6.4223472785949705
# self.data.close 6.070295810699463
# adversarial_action [1.]
# self.data.close mods 6.252404685020447
# self.data.close 6.052433490753174
# adversarial_action [1.]
# self.data.close mods 6.234006495475769
# self.data.close 6.232868194580078
# adversarial_action [1.]
# self.data.close mods 6.4198542404174805
# self.data.close 6.232868194580078
# adversarial_action [1.]
# self.data.close mods 6.4198542404174805
# self.data.close 6.232868194580078
# adversarial_action [1.]
# self.data.close mods 6.4198542404174805
# self.data.close 6.189273834228516
# adversarial_action [1.]
# self.data.close mods 6.374952049255371
# self.data.close 6.181704998016357
# adversarial_action [1.]
# self.data.close mods 6.367156147956848
# self.data.close 6.072718143463135
# adversarial_action [1.]
# self.data.close mods 6.254899687767029
# self.data.close 6.072718143463135
# adversarial_action [1.]
# self.data.close mods 6.254899687767029
# self.data.close 6.052131175994873
# adversarial_action [1.]
# self.data.close mods 6.233695111274719
# self.data.close 6.052131175994873
# adversarial_action [1.]
# self.data.close mods 6.233695111274719
# self.data.close 6.052131175994873
# adversarial_action [1.]
# self.data.close mods 6.233695111274719
# self.data.close 5.963123798370361
# adversarial_action [1.]
# self.data.close mods 6.142017512321472
# self.data.close 5.9407196044921875
# adversarial_action [1.]
# self.data.close mods 6.118941192626953
# self.data.close 5.948288917541504
# adversarial_action [1.]
# self.data.close mods 6.126737585067749
# self.data.close 5.8526225090026855
# adversarial_action [1.]
# self.data.close mods 6.028201184272766
# self.data.close 5.720324516296387
# adversarial_action [1.]
# self.data.close mods 5.891934251785279
# self.data.close 5.720324516296387
# adversarial_action [1.]
# self.data.close mods 5.891934251785279
# self.data.close 5.720324516296387
# adversarial_action [1.]
# self.data.close mods 5.891934251785279
# self.data.close 5.748178005218506
# adversarial_action [1.]
# self.data.close mods 5.920623345375061
# self.data.close 5.988254070281982
# adversarial_action [1.]
# self.data.close mods 6.167901692390442
# self.data.close 5.946775436401367
# adversarial_action [1.]
# self.data.close mods 6.125178699493408
# self.data.close 5.893494129180908
# adversarial_action [1.]
# self.data.close mods 6.070298953056335
# self.data.close 5.963426113128662
# adversarial_action [1.]
# self.data.close mods 6.142328896522522
# self.data.close 5.963426113128662
# adversarial_action [1.]
# self.data.close mods 6.142328896522522
# self.data.close 5.963426113128662
# adversarial_action [1.]
# self.data.close mods 6.142328896522522
# self.data.close 5.878355979919434
# adversarial_action [1.]
# self.data.close mods 6.0547066593170165
# self.data.close 5.904392242431641
# adversarial_action [1.]
# self.data.close mods 6.08152400970459
# self.data.close 5.808422565460205
# adversarial_action [1.]
# self.data.close mods 5.982675242424011
# self.data.close 5.91650390625
# adversarial_action [1.]
# self.data.close mods 6.0939990234375
# self.data.close 6.001270294189453
# adversarial_action [1.]
# self.data.close mods 6.181308403015137
# self.data.close 6.001270294189453
# adversarial_action [1.]
# self.data.close mods 6.181308403015137
# self.data.close 6.001270294189453
# adversarial_action [1.]
# self.data.close mods 6.181308403015137
# self.data.close 6.065753936767578
# adversarial_action [1.]
# self.data.close mods 6.247726554870606
# self.data.close 6.118431091308594
# adversarial_action [1.]
# self.data.close mods 6.301984024047852
# self.data.close 6.328535079956055
# adversarial_action [1.]
# self.data.close mods 6.518391132354736
# self.data.close 6.406339168548584
# adversarial_action [1.]
# self.data.close mods 6.598529343605041
# self.data.close 6.406339168548584
# adversarial_action [1.]
# self.data.close mods 6.598529343605041
# self.data.close 6.406339168548584
# adversarial_action [1.]
# self.data.close mods 6.598529343605041
# self.data.close 6.406339168548584
# adversarial_action [1.]
# self.data.close mods 6.598529343605041
# self.data.close 6.330350399017334
# adversarial_action [1.]
# self.data.close mods 6.520260910987854
# self.data.close 6.407247066497803
# adversarial_action [1.]
# self.data.close mods 6.599464478492737
# self.data.close 6.379697799682617
# adversarial_action [1.]
# self.data.close mods 6.571088733673096
# self.data.close 6.478997707366943
# adversarial_action [1.]
# self.data.close mods 6.673367638587952
# self.data.close 6.478997707366943
# adversarial_action [1.]
# self.data.close mods 6.673367638587952
# self.data.close 6.478997707366943
# adversarial_action [1.]
# self.data.close mods 6.673367638587952
# self.data.close 6.478997707366943
# adversarial_action [1.]
# self.data.close mods 6.673367638587952
# self.data.close 6.490199565887451
# adversarial_action [1.]
# self.data.close mods 6.684905552864075
# self.data.close 6.386963844299316
# adversarial_action [1.]
# self.data.close mods 6.578572759628296
# self.data.close 6.375156402587891
# adversarial_action [1.]
# self.data.close mods 6.566411094665527
# self.data.close 6.417540550231934
# adversarial_action [1.]
# self.data.close mods 6.610066766738892
# self.data.close 6.360929489135742
# adversarial_action [1.]
# self.data.close mods 6.5517573738098145
# self.data.close 6.360929489135742
# adversarial_action [1.]
# self.data.close mods 6.5517573738098145
# self.data.close 6.360929489135742
# adversarial_action [1.]
# self.data.close mods 6.5517573738098145
# self.data.close 6.288571357727051
# adversarial_action [1.]
# self.data.close mods 6.477228498458863
# self.data.close 6.377274990081787
# adversarial_action [1.]
# self.data.close mods 6.568593239784241
# self.data.close 6.340342998504639
# adversarial_action [1.]
# self.data.close mods 6.530553288459778
# self.data.close 6.234381675720215
# adversarial_action [1.]
# self.data.close mods 6.421413125991822
# self.data.close 6.510180473327637
# adversarial_action [1.]
# self.data.close mods 6.705485887527466
# self.data.close 6.510180473327637
# adversarial_action [1.]
# self.data.close mods 6.705485887527466
# self.data.close 6.510180473327637
# adversarial_action [1.]
# self.data.close mods 6.705485887527466
# self.data.close 6.510180473327637
# adversarial_action [1.]
# self.data.close mods 6.705485887527466
# self.data.close 6.409973621368408
# adversarial_action [1.]
# self.data.close mods 6.60227283000946
# self.data.close 6.299169063568115
# adversarial_action [1.]
# self.data.close mods 6.488144135475159
# self.data.close 5.986738681793213
# adversarial_action [1.]
# self.data.close mods 6.16634084224701
# self.data.close 6.14779806137085
# adversarial_action [1.]
# self.data.close mods 6.332232003211975
# self.data.close 6.14779806137085
# adversarial_action [1.]
# self.data.close mods 6.332232003211975
# self.data.close 6.14779806137085
# adversarial_action [1.]
# self.data.close mods 6.332232003211975
# self.data.close 6.234683990478516
# adversarial_action [1.]
# self.data.close mods 6.421724510192871
# self.data.close 6.293417453765869
# adversarial_action [1.]
# self.data.close mods 6.482219977378845
# self.data.close 6.033360481262207
# adversarial_action [1.]
# self.data.close mods 6.214361295700074
# self.data.close 5.814477443695068
# adversarial_action [1.]
# self.data.close mods 5.988911767005921
# self.data.close 5.895309925079346
# adversarial_action [1.]
# self.data.close mods 6.072169222831726
# self.data.close 5.895309925079346
# adversarial_action [1.]
# self.data.close mods 6.072169222831726
# self.data.close 5.895309925079346
# adversarial_action [1.]
# self.data.close mods 6.072169222831726
# self.data.close 5.929521083831787
# adversarial_action [1.]
# self.data.close mods 6.107406716346741
# self.data.close 6.031544208526611
# adversarial_action [1.]
# self.data.close mods 6.21249053478241
# self.data.close 5.814175605773926
# adversarial_action [1.]
# self.data.close mods 5.988600873947144
# self.data.close 5.917409896850586
# adversarial_action [1.]
# self.data.close mods 6.094932193756104
# self.data.close 5.87684440612793
# adversarial_action [1.]
# self.data.close mods 6.053149738311768
# self.data.close 5.87684440612793
# adversarial_action [1.]
# self.data.close mods 6.053149738311768
# self.data.close 5.87684440612793
# adversarial_action [1.]
# self.data.close mods 6.053149738311768
# self.data.close 5.939509391784668
# adversarial_action [1.]
# self.data.close mods 6.1176946735382085
# self.data.close 5.907118320465088
# adversarial_action [1.]
# self.data.close mods 6.0843318700790405
# self.data.close 6.014590740203857
# adversarial_action [1.]
# self.data.close mods 6.195028462409973
# self.data.close 6.066361427307129
# adversarial_action [1.]
# self.data.close mods 6.248352270126343
# self.data.close 6.15778923034668
# adversarial_action [1.]
# self.data.close mods 6.34252290725708
# self.data.close 6.15778923034668
# adversarial_action [1.]
# self.data.close mods 6.34252290725708
# self.data.close 6.15778923034668
# adversarial_action [1.]
# self.data.close mods 6.34252290725708
# self.data.close 6.15778923034668
# adversarial_action [1.]
# self.data.close mods 6.34252290725708
# self.data.close 6.132054328918457
# adversarial_action [1.]
# self.data.close mods 6.316015958786011
# self.data.close 6.143559455871582
# adversarial_action [1.]
# self.data.close mods 6.327866239547729
# self.data.close 6.105414390563965
# adversarial_action [1.]
# self.data.close mods 6.288576822280884
# self.data.close 6.067569732666016
# adversarial_action [1.]
# self.data.close mods 6.249596824645996
# self.data.close 6.067569732666016
# adversarial_action [1.]
# self.data.close mods 6.249596824645996
# self.data.close 6.067569732666016
# adversarial_action [1.]
# self.data.close mods 6.249596824645996
# self.data.close 5.965849876403809
# adversarial_action [1.]
# self.data.close mods 6.144825372695923
# self.data.close 6.074836730957031
# adversarial_action [1.]
# self.data.close mods 6.257081832885742
# self.data.close 6.115403652191162
# adversarial_action [1.]
# self.data.close mods 6.298865761756897
# self.data.close 6.194721698760986
# adversarial_action [1.]
# self.data.close mods 6.380563349723816
# self.data.close 6.327020645141602
# adversarial_action [1.]
# self.data.close mods 6.51683126449585
# self.data.close 6.327020645141602
# adversarial_action [1.]
# self.data.close mods 6.51683126449585
# self.data.close 6.327020645141602
# adversarial_action [1.]
# self.data.close mods 6.51683126449585
# self.data.close 6.32278299331665
# adversarial_action [1.]
# self.data.close mods 6.5124664831161505
# self.data.close 6.337314128875732
# adversarial_action [1.]
# self.data.close mods 6.527433552742004
# self.data.close 6.379092693328857
# adversarial_action [1.]
# self.data.close mods 6.570465474128723
# self.data.close 6.6285529136657715
# adversarial_action [1.]
# self.data.close mods 6.827409501075745
# self.data.close 6.63248872756958
# adversarial_action [1.]
# self.data.close mods 6.831463389396668
# self.data.close 6.63248872756958
# adversarial_action [1.]
# self.data.close mods 6.831463389396668
# self.data.close 6.63248872756958
# adversarial_action [1.]
# self.data.close mods 6.831463389396668
# self.data.close 6.751770973205566
# adversarial_action [1.]
# self.data.close mods 6.954324102401734
# self.data.close 6.806869029998779
# adversarial_action [1.]
# self.data.close mods 7.011075100898743
# self.data.close 6.826850891113281
# adversarial_action [1.]
# self.data.close mods 7.03165641784668
# self.data.close 6.860151290893555
# adversarial_action [1.]
# self.data.close mods 7.0659558296203615
# self.data.close 6.776594161987305
# adversarial_action [1.]
# self.data.close mods 6.979891986846924
# self.data.close 6.776594161987305
# adversarial_action [1.]
# self.data.close mods 6.979891986846924
# self.data.close 6.776594161987305
# adversarial_action [1.]
# self.data.close mods 6.979891986846924
# self.data.close 6.795061111450195
# adversarial_action [1.]
# self.data.close mods 6.998912944793702
# self.data.close 6.78507137298584
# adversarial_action [1.]
# self.data.close mods 6.988623514175416
# self.data.close 6.801115036010742
# adversarial_action [1.]
# self.data.close mods 7.0051484870910645
# self.data.close 6.728458404541016
# adversarial_action [1.]
# self.data.close mods 6.930312156677246
# self.data.close 6.804144859313965
# adversarial_action [1.]
# self.data.close mods 7.008269205093384
# self.data.close 6.804144859313965
# adversarial_action [1.]
# self.data.close mods 7.008269205093384
# self.data.close 6.804144859313965
# adversarial_action [1.]
# self.data.close mods 7.008269205093384
# self.data.close 6.913432598114014
# adversarial_action [1.]
# self.data.close mods 7.120835576057434
# self.data.close 6.944010257720947
# adversarial_action [1.]
# self.data.close mods 7.1523305654525755
# self.data.close 6.86166524887085
# adversarial_action [1.]
# self.data.close mods 7.067515206336975
# self.data.close 6.990330696105957
# adversarial_action [1.]
# self.data.close mods 7.200040616989136
# self.data.close 7.035439491271973
# adversarial_action [1.]
# self.data.close mods 7.246502676010132
# self.data.close 7.035439491271973
# adversarial_action [1.]
# self.data.close mods 7.246502676010132
# self.data.close 7.035439491271973
# adversarial_action [1.]
# self.data.close mods 7.246502676010132
# self.data.close 7.140186786651611
# adversarial_action [1.]
# self.data.close mods 7.35439239025116
# self.data.close 7.114453315734863
# adversarial_action [1.]
# self.data.close mods 7.32788691520691
# self.data.close 7.143819332122803
# adversarial_action [1.]
# self.data.close mods 7.358133912086487
# self.data.close 7.220108985900879
# adversarial_action [1.]
# self.data.close mods 7.4367122554779055
# self.data.close 7.220108985900879
# adversarial_action [1.]
# self.data.close mods 7.4367122554779055
# self.data.close 7.220108985900879
# adversarial_action [1.]
# self.data.close mods 7.4367122554779055
# self.data.close 7.220108985900879
# adversarial_action [1.]
# self.data.close mods 7.4367122554779055
# self.data.close 7.251901149749756
# adversarial_action [1.]
# self.data.close mods 7.4694581842422485
# self.data.close 7.283994197845459
# adversarial_action [1.]
# self.data.close mods 7.502514023780823
# self.data.close 7.264312744140625
# adversarial_action [1.]
# self.data.close mods 7.482242126464844
# self.data.close 7.320018291473389
# adversarial_action [1.]
# self.data.close mods 7.5396188402175905
# self.data.close 7.3351545333862305
# adversarial_action [1.]
# self.data.close mods 7.555209169387817
# self.data.close 7.3351545333862305
# adversarial_action [1.]
# self.data.close mods 7.555209169387817
# self.data.close 7.3351545333862305
# adversarial_action [1.]
# self.data.close mods 7.555209169387817
# self.data.close 7.339389324188232
# adversarial_action [1.]
# self.data.close mods 7.55957100391388
# self.data.close 7.438086032867432
# adversarial_action [1.]
# self.data.close mods 7.661228613853455
# self.data.close 7.535874843597412
# adversarial_action [1.]
# self.data.close mods 7.7619510889053345
# self.data.close 7.489856719970703
# adversarial_action [1.]
# self.data.close mods 7.714552421569825
# self.data.close 7.479864120483398
# adversarial_action [1.]
# self.data.close mods 7.704260044097901
# self.data.close 7.479864120483398
# adversarial_action [1.]
# self.data.close mods 7.704260044097901
# self.data.close 7.479864120483398
# adversarial_action [1.]
# self.data.close mods 7.704260044097901
# self.data.close 7.404788970947266
# adversarial_action [1.]
# self.data.close mods 7.626932640075684
# self.data.close 7.847698211669922
# adversarial_action [1.]
# self.data.close mods 8.08312915802002
# self.data.close 8.067187309265137
# adversarial_action [1.]
# self.data.close mods 8.30920292854309
# self.data.close 8.199180603027344
# adversarial_action [1.]
# self.data.close mods 8.445156021118164
# self.data.close 8.158915519714355
# adversarial_action [1.]
# self.data.close mods 8.403682985305787
# self.data.close 8.158915519714355
# adversarial_action [1.]
# self.data.close mods 8.403682985305787
# self.data.close 8.158915519714355
# adversarial_action [1.]
# self.data.close mods 8.403682985305787
# self.data.close 7.933071613311768
# adversarial_action [1.]
# self.data.close mods 8.171063761711121
# self.data.close 7.919755458831787
# adversarial_action [1.]
# self.data.close mods 8.15734812259674
# self.data.close 8.13288402557373
# adversarial_action [1.]
# self.data.close mods 8.376870546340943
# self.data.close 7.9043121337890625
# adversarial_action [1.]
# self.data.close mods 8.141441497802735
# self.data.close 8.06355094909668
# adversarial_action [1.]
# self.data.close mods 8.30545747756958
# self.data.close 8.06355094909668
# adversarial_action [1.]
# self.data.close mods 8.30545747756958
# self.data.close 8.06355094909668
# adversarial_action [1.]
# self.data.close mods 8.30545747756958
# self.data.close 7.8313517570495605
# adversarial_action [1.]
# self.data.close mods 8.066292309761048
# self.data.close 7.749912738800049
# adversarial_action [1.]
# self.data.close mods 7.98241012096405
# self.data.close 7.45504093170166
# adversarial_action [1.]
# self.data.close mods 7.6786921596527105
# self.data.close 7.140491008758545
# adversarial_action [1.]
# self.data.close mods 7.354705739021301
# self.data.close 7.689365863800049
# adversarial_action [1.]
# self.data.close mods 7.92004683971405
# self.data.close 7.689365863800049
# adversarial_action [1.]
# self.data.close mods 7.92004683971405
# self.data.close 7.689365863800049
# adversarial_action [1.]
# self.data.close mods 7.92004683971405
# ...
# self.data.close 27.191213607788086
# adversarial_action [-1.]
# self.data.close mods 26.375477199554442
# self.data.close 27.110200881958008
# adversarial_action [1.]
# self.data.close mods 27.923506908416748
# self.data.close 27.09630584716797
# adversarial_action [-1.]
# self.data.close mods 26.283416671752928
# self.data.close 26.98982810974121
# adversarial_action [0.05490845]
# self.data.close mods 27.034287202136756
# self.data.close 27.232881546020508
# adversarial_action [-1.]
# self.data.close mods 26.415895099639894
# self.data.close 27.232881546020508
# adversarial_action [-0.82518554]
# self.data.close mods 26.558716146265848
# self.data.close 27.232881546020508
# adversarial_action [-1.]
# self.data.close mods 26.415895099639894
# self.data.close 27.37175941467285
# adversarial_action [0.50153327]
# self.data.close mods 27.78359485472295
# self.data.close 26.756040573120117
# adversarial_action [1.]
# self.data.close mods 27.558721790313722
# self.data.close 26.49910545349121
# adversarial_action [0.2291202]
# self.data.close mods 26.6812498596861
# self.data.close 26.32318115234375
# adversarial_action [-1.]
# self.data.close mods 25.533485717773438
# self.data.close 26.28152084350586
# adversarial_action [-1.]
# self.data.close mods 25.493075218200683
# self.data.close 26.28152084350586
# adversarial_action [-0.01485679]
# self.data.close mods 26.26980707594405
# self.data.close 26.28152084350586
# adversarial_action [-0.39931512]
# self.data.close mods 25.966682584977924
# self.data.close 25.80699920654297
# adversarial_action [-0.59699225]
# self.data.close mods 25.34480184758513
# self.data.close 25.83014488220215
# adversarial_action [-0.52568036]
# self.data.close mods 25.42279288392346
# self.data.close 25.553279876708984
# adversarial_action [1.]
# self.data.close mods 26.319878273010254
# self.data.close 25.322948455810547
# adversarial_action [1.]
# self.data.close mods 26.082636909484865
# self.data.close 25.6882266998291
# adversarial_action [-1.]
# self.data.close mods 24.917579898834227
# self.data.close 25.6882266998291
# adversarial_action [-0.17115197]
# self.data.close mods 25.556328984857764
# self.data.close 25.6882266998291
# adversarial_action [-1.]
# self.data.close mods 24.917579898834227
# self.data.close 25.839448928833008
# adversarial_action [-1.]
# self.data.close mods 25.064265460968016
# self.data.close 25.797576904296875
# adversarial_action [-0.08950531]
# self.data.close mods 25.728306297019117
# self.data.close 25.078645706176758
# adversarial_action [0.7572355]
# self.data.close mods 25.648358951138672
# self.data.close 25.227556228637695
# adversarial_action [1.]
# self.data.close mods 25.984382915496827
# self.data.close 24.59471321105957
# adversarial_action [0.0281496]
# self.data.close mods 24.615483154769446
# self.data.close 24.59471321105957
# adversarial_action [-1.]
# self.data.close mods 23.856871814727782
# self.data.close 24.59471321105957
# adversarial_action [-1.]
# self.data.close mods 23.856871814727782
# self.data.close 24.92043685913086
# adversarial_action [-0.5561129]
# self.data.close mods 24.50467957765988
# self.data.close 25.59050750732422
# adversarial_action [-1.]
# self.data.close mods 24.82279228210449
# self.data.close 25.581199645996094
# adversarial_action [-1.]
# self.data.close mods 24.81376365661621
# self.data.close 25.606796264648438
# adversarial_action [-0.27936286]
# self.data.close mods 25.39218863149262
# self.data.close 25.995338439941406
# adversarial_action [-1.]
# self.data.close mods 25.215478286743163
# self.data.close 25.995338439941406
# adversarial_action [-0.91236633]
# self.data.close mods 25.283820293568347
# self.data.close 25.995338439941406
# adversarial_action [-0.6322869]
# self.data.close mods 25.50224307637399
# self.data.close 26.011627197265625
# adversarial_action [0.90278995]
# self.data.close mods 26.71611826606011
# self.data.close 25.879009246826172
# adversarial_action [0.37339103]
# self.data.close mods 26.168898946090444
# self.data.close 26.009300231933594
# adversarial_action [-1.]
# self.data.close mods 25.229021224975586
# self.data.close 26.009300231933594
# adversarial_action [-1.]
# self.data.close mods 25.229021224975586
# self.data.close 25.958110809326172
# adversarial_action [-1.]
# self.data.close mods 25.179367485046384
# self.data.close 25.958110809326172
# adversarial_action [-0.4410549]
# self.data.close mods 25.61464224219471
# self.data.close 25.958110809326172
# adversarial_action [-0.5691737]
# self.data.close mods 25.514870595035177
# self.data.close 25.93252182006836
# adversarial_action [0.102162]
# self.data.close mods 26.012001371630074
# self.data.close 25.71381950378418
# adversarial_action [-0.17946845]
# self.data.close mods 25.57537492162587
# self.data.close 25.47417449951172
# adversarial_action [-1.]
# self.data.close mods 24.709949264526365
# self.data.close 25.569564819335938
# adversarial_action [-0.27673686]
# self.data.close mods 25.357283590392452
# self.data.close 25.385766983032227
# adversarial_action [-1.]
# self.data.close mods 24.62419397354126
# self.data.close 25.385766983032227
# adversarial_action [-1.]
# self.data.close mods 24.62419397354126
# self.data.close 25.385766983032227
# adversarial_action [-1.]
# self.data.close mods 24.62419397354126
# self.data.close 25.581199645996094
# adversarial_action [-0.01165771]
# self.data.close mods 25.572253096071073
# self.data.close 25.832481384277344
# adversarial_action [-1.]
# self.data.close mods 25.057506942749022
# self.data.close 26.08607292175293
# adversarial_action [-1.]
# self.data.close mods 25.30349073410034
# self.data.close 26.511850357055664
# adversarial_action [-0.3325159]
# self.data.close mods 26.24738200727656
# self.data.close 26.360614776611328
# adversarial_action [-1.]
# self.data.close mods 25.569796333312986
# self.data.close 26.360614776611328
# adversarial_action [-1.]
# self.data.close mods 25.569796333312986
# self.data.close 26.360614776611328
# adversarial_action [-1.]
# self.data.close mods 25.569796333312986
# self.data.close 26.80034637451172
# adversarial_action [-0.62823665]
# self.data.close mods 26.29523757861466
# self.data.close 26.80034637451172
# adversarial_action [-0.6781159]
# self.data.close mods 26.25513414096747
# self.data.close 26.946922302246094
# adversarial_action [-0.88319325]
# self.data.close mods 26.232942102063298
# self.data.close 26.981826782226562
# adversarial_action [1.]
# self.data.close mods 27.79128158569336
# self.data.close 27.13770866394043
# adversarial_action [-1.]
# self.data.close mods 26.323577404022217
# self.data.close 27.13770866394043
# adversarial_action [-1.]
# self.data.close mods 26.323577404022217
# self.data.close 27.13770866394043
# adversarial_action [-1.]
# self.data.close mods 26.323577404022217
# self.data.close 27.209836959838867
# adversarial_action [-0.5635006]
# self.data.close mods 26.749854189992465
# self.data.close 27.235422134399414
# adversarial_action [0.40423906]
# self.data.close mods 27.565710776438767
# self.data.close 27.056276321411133
# adversarial_action [-1.]
# self.data.close mods 26.2445880317688
# self.data.close 27.10978889465332
# adversarial_action [0.32894373]
# self.data.close mods 27.37731674652146
# self.data.close 27.281959533691406
# adversarial_action [-0.64397204]
# self.data.close mods 26.754894960244318
# self.data.close 27.281959533691406
# adversarial_action [-0.46413332]
# self.data.close mods 26.902085538224608
# self.data.close 27.281959533691406
# adversarial_action [0.13008648]
# self.data.close mods 27.38842995747458
# self.data.close 27.281959533691406
# adversarial_action [0.97414017]
# self.data.close mods 28.079253112371955
# self.data.close 27.16562843322754
# adversarial_action [0.67706275]
# self.data.close mods 27.717413485889995
# self.data.close 27.158649444580078
# adversarial_action [-0.78807104]
# self.data.close mods 26.5165610941795
# self.data.close 26.946922302246094
# adversarial_action [0.4488948]
# self.data.close mods 27.309812300164616
# self.data.close 27.02370834350586
# adversarial_action [-1.]
# self.data.close mods 26.212997093200684
# self.data.close 27.02370834350586
# adversarial_action [0.49419236]
# self.data.close mods 27.424355651057677
# self.data.close 27.02370834350586
# adversarial_action [1.]
# self.data.close mods 27.834419593811035
# self.data.close 27.02370834350586
# adversarial_action [-0.3429103]
# self.data.close mods 26.74570711374845
# self.data.close 26.993459701538086
# adversarial_action [-1.]
# self.data.close mods 26.183655910491943
# self.data.close 27.130727767944336
# adversarial_action [-0.49144095]
# self.data.close mods 26.730733247605492
# self.data.close 27.43319320678711
# adversarial_action [-0.5918163]
# self.data.close mods 26.946130874730375
# self.data.close 27.684465408325195
# adversarial_action [0.07952029]
# self.data.close mods 27.75050970581307
# self.data.close 27.684465408325195
# adversarial_action [-0.931116]
# self.data.close mods 26.911141960058256
# self.data.close 27.684465408325195
# adversarial_action [-1.]
# self.data.close mods 26.85393144607544
# self.data.close 27.712387084960938
# adversarial_action [0.05341214]
# self.data.close mods 27.756792421436685
# self.data.close 27.861289978027344
# adversarial_action [-1.]
# self.data.close mods 27.02545127868652
# self.data.close 27.744958877563477
# adversarial_action [-1.]
# self.data.close mods 26.91261011123657
# self.data.close 27.69609832763672
# adversarial_action [-0.04539713]
# self.data.close mods 27.65837862415907
# self.data.close 27.919456481933594
# adversarial_action [0.7260611]
# self.data.close mods 28.527593425271643
# self.data.close 27.919456481933594
# adversarial_action [-1.]
# self.data.close mods 27.081872787475586
# self.data.close 27.919456481933594
# adversarial_action [-1.]
# self.data.close mods 27.081872787475586
# self.data.close 27.919456481933594
# adversarial_action [-1.]
# self.data.close mods 27.081872787475586
# self.data.close 27.917125701904297
# adversarial_action [-1.]
# self.data.close mods 27.079611930847168
# self.data.close 27.868268966674805
# adversarial_action [0.6071147]
# self.data.close mods 28.375846016414606
# self.data.close 27.919456481933594
# adversarial_action [0.17756176]
# self.data.close mods 28.06817931682592
# self.data.close 27.93807029724121
# adversarial_action [-0.9727864]
# self.data.close mods 27.122737030171404
# self.data.close 27.93807029724121
# adversarial_action [-0.8867518]
# self.data.close mods 27.194846297831635
# self.data.close 27.93807029724121
# adversarial_action [1.]
# self.data.close mods 28.776212406158447
# self.data.close 27.912477493286133
# adversarial_action [0.49982715]
# self.data.close mods 28.33101991262782
# self.data.close 28.356857299804688
# adversarial_action [0.31387287]
# self.data.close mods 28.623870748569107
# self.data.close 28.37081527709961
# adversarial_action [-1.]
# self.data.close mods 27.51969081878662
# self.data.close 28.373146057128906
# adversarial_action [-0.3583959]
# self.data.close mods 28.068081476957275
# self.data.close 28.298696517944336
# adversarial_action [-0.32065693]
# self.data.close mods 28.02647132736237
# self.data.close 28.298696517944336
# adversarial_action [-0.74570626]
# self.data.close mods 27.66562106347274
# self.data.close 28.298696517944336
# adversarial_action [-0.84390604]
# self.data.close mods 27.582253286264866
# self.data.close 28.23354721069336
# adversarial_action [1.]
# self.data.close mods 29.08055362701416
# self.data.close 29.95525360107422
# adversarial_action [0.4309287]
# self.data.close mods 30.342510962249616
# self.data.close 29.90406036376953
# adversarial_action [-1.]
# self.data.close mods 29.006938552856443
# self.data.close 30.03203010559082
# adversarial_action [0.0301348]
# self.data.close mods 30.059180379599436
# self.data.close 30.31354522705078
# adversarial_action [0.5760398]
# self.data.close mods 30.83739947486003
# self.data.close 30.31354522705078
# adversarial_action [0.21043992]
# self.data.close mods 30.504920628412563
# self.data.close 30.31354522705078
# adversarial_action [-1.]
# self.data.close mods 29.404138870239258
# self.data.close 30.602046966552734
# adversarial_action [-1.]
# self.data.close mods 29.683985557556152
# self.data.close 30.720705032348633
# adversarial_action [-1.]
# self.data.close mods 29.799083881378174
# self.data.close 30.94269561767578
# adversarial_action [1.]
# self.data.close mods 31.870976486206054
# self.data.close 30.872594833374023
# adversarial_action [1.]
# self.data.close mods 31.798772678375244
# self.data.close 31.145980834960938
# adversarial_action [-0.11515918]
# self.data.close mods 31.038378463068288
# self.data.close 31.145980834960938
# adversarial_action [-0.2188847]
# self.data.close mods 30.94145946875211
# self.data.close 31.145980834960938
# adversarial_action [-0.43402618]
# self.data.close mods 30.740435700849968
# self.data.close 31.550251007080078
# adversarial_action [-1.]
# self.data.close mods 30.603743476867674
# self.data.close 31.664730072021484
# adversarial_action [-0.7145777]
# self.data.close mods 30.985922796318007
# self.data.close 31.627357482910156
# adversarial_action [-0.06655368]
# self.data.close mods 31.564209970053316
# self.data.close 31.713804244995117
# adversarial_action [-1.]
# self.data.close mods 30.762390117645264
# self.data.close 31.942798614501953
# adversarial_action [-1.]
# self.data.close mods 30.984514656066892
# self.data.close 31.942798614501953
# adversarial_action [-1.]
# self.data.close mods 30.984514656066892
# self.data.close 31.942798614501953
# adversarial_action [-1.]
# self.data.close mods 30.984514656066892
# self.data.close 31.942798614501953
# adversarial_action [0.85824907]
# self.data.close mods 32.76524492895753
# self.data.close 32.038604736328125
# adversarial_action [0.40822667]
# self.data.close mods 32.4309751228968
# self.data.close 31.903087615966797
# adversarial_action [-1.]
# self.data.close mods 30.945994987487794
# self.data.close 31.933454513549805
# adversarial_action [-1.]
# self.data.close mods 30.97545087814331
# self.data.close 31.996543884277344
# adversarial_action [-1.]
# self.data.close mods 31.03664756774902
# self.data.close 31.996543884277344
# adversarial_action [0.75286496]
# self.data.close mods 32.719216183206456
# self.data.close 31.996543884277344
# adversarial_action [1.]
# self.data.close mods 32.956440200805666
# self.data.close 32.01056671142578
# adversarial_action [-1.]
# self.data.close mods 31.05024971008301
# self.data.close 32.66484832763672
# adversarial_action [-0.05068314]
# self.data.close mods 32.615181614471105
# self.data.close 32.47090148925781
# adversarial_action [-0.18495932]
# self.data.close mods 32.29072761132377
# self.data.close 32.66252136230469
# adversarial_action [-0.49409842]
# self.data.close mods 32.178366351542095
# self.data.close 32.55970001220703
# adversarial_action [-0.5800257]
# self.data.close mods 31.99313615492465
# self.data.close 32.55970001220703
# adversarial_action [-1.]
# self.data.close mods 31.58290901184082
# self.data.close 32.55970001220703
# adversarial_action [-0.964754]
# self.data.close mods 31.617337001696022
# self.data.close 32.60176086425781
# adversarial_action [-0.3936902]
# self.data.close mods 32.21671105291845
# self.data.close 32.48025131225586
# adversarial_action [-1.]
# self.data.close mods 31.505843772888184
# self.data.close 32.40547180175781
# adversarial_action [1.]
# self.data.close mods 33.37763595581055
# self.data.close 32.51295471191406
# adversarial_action [-0.37747812]
# self.data.close mods 32.14476683866065
# self.data.close 32.5269889831543
# adversarial_action [0.20381457]
# self.data.close mods 32.72587320757308
# self.data.close 32.5269889831543
# adversarial_action [-1.]
# self.data.close mods 31.551179313659667
# self.data.close 32.5269889831543
# adversarial_action [0.20952994]
# self.data.close mods 32.73145032105773
# self.data.close 32.47792434692383
# adversarial_action [-0.19903499]
# self.data.close mods 32.28399704758661
# self.data.close 32.82140350341797
# adversarial_action [-0.24188796]
# self.data.close mods 32.58323043637867
# self.data.close 32.875152587890625
# adversarial_action [1.]
# self.data.close mods 33.861407165527346
# self.data.close 32.711585998535156
# adversarial_action [-0.5510219]
# self.data.close mods 32.170842016030534
# self.data.close 33.05508804321289
# adversarial_action [-0.17528608]
# self.data.close mods 32.881265134621714
# self.data.close 33.05508804321289
# adversarial_action [-0.5281241]
# self.data.close mods 32.531372390456205
# self.data.close 33.05508804321289
# adversarial_action [0.8131012]
# self.data.close mods 33.861401968511345
# self.data.close 32.67652893066406
# adversarial_action [-1.]
# self.data.close mods 31.696233062744138

# %% [markdown]
# ### Model 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/ddpg/ddpg_50000"
if if_using_ddpg:
    if not os.path.exists(model_file_path+'.zip'):
        trained_ddpg = agent.train_model(model=model_ddpg, 
                                tb_log_name='ddpg',
                                total_timesteps=50000)
        trained_ddpg.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_ddpg = MODELS['ddpg'].load(model_file_path)
        trained_ddpg.env = env_train
        print("agent loaded from", model_file_path)

# %% [markdown]
# ### Model 3: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/a2c/a2c_50000"
if if_using_a2c:
    if not os.path.exists(model_file_path+'.zip'):
        trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000) 
        trained_a2c.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_a2c = MODELS['a2c'].load(model_file_path)
        trained_a2c.env = env_train
        print("agent loaded from", model_file_path)

# %% [markdown]
# ### Model 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/td3/td3_30000"
if if_using_td3:
    if not os.path.exists(model_file_path+'.zip'):
        trained_td3 = agent.train_model(model=model_td3, 
                                tb_log_name='td3',
                                total_timesteps=30000) 
        trained_td3.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_td3 = MODELS['td3'].load(model_file_path)
        trained_td3.env = env_train
        print("agent loaded from", model_file_path)

# %% [markdown]
# ### Model 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
model_file_path = f"{TRAINED_MODEL_DIR}/sac/sac_40000"
if if_using_sac:
    if not os.path.exists(model_file_path+'.zip'):
        trained_sac = agent.train_model(model=model_sac, 
                                tb_log_name='sac',
                                total_timesteps=40000) 
        trained_sac.save(model_file_path)
        print("agent saved to", model_file_path)
    else:
        trained_sac = MODELS['sac'].load(model_file_path)
        trained_sac.env = env_train
        print("agent loaded from", model_file_path)

# %% [markdown]
# ## Trading
# Trade starting with $1,000,000 initial capital at TEST_START_DATE.

# %%
trade_data = data_split(processed_full, TEST_START_DATE, TEST_END_DATE)
e_trade_gym = StockTradingEnv(df = trade_data, **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade_data.head()
# Out:
#         date   tic       open       high        low      close       volume  \
# 0 2019-01-01  AAPL  38.722500  39.712502  38.557499  37.893330  148158800.0
# 1 2019-01-02  AAPL  38.722500  39.712502  38.557499  37.893330  148158800.0
# 2 2019-01-03  AAPL  35.994999  36.430000  35.500000  34.118877  365248800.0
# 3 2019-01-04  AAPL  36.132500  37.137501  35.950001  35.575386  234428400.0
# 4 2019-01-05  AAPL  37.174999  37.207500  36.474998  35.496208  219111200.0
#
#         OPM       NPM      ROA  ...  quick_ratio  cash_ratio  inv_turnover  \
# 0  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
# 1  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
# 2  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
# 3  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
# 4  0.258891  0.227773  0.13336  ...     1.134347    0.854114     23.571867
#
#    acc_rec_turnover  acc_pay_turnover  debt_ratio  debt_to_equity        PE  \
# 0          7.620024          3.781658    0.690466        2.230663  5.655721
# 1          7.620024          3.781658    0.690466        2.230663  5.655721
# 2          7.620024          3.781658    0.690466        2.230663  5.092370
# 3          7.620024          3.781658    0.690466        2.230663  5.309759
# 4          7.620024          3.781658    0.690466        2.230663  5.297942
#
#          PB  Div_yield
# 0  1.649210   0.019265
# 1  1.649210   0.019265
# 2  1.484936   0.021396
# 3  1.548327   0.020520
# 4  1.544881   0.020566
#
# [5 rows x 22 columns]

# %%
if if_using_ppo:
    df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
        model=trained_ppo, 
        environment = e_trade_gym) 

if if_using_ddpg:
    df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
        model=trained_ddpg, 
        environment = e_trade_gym) 
if if_using_a2c:
    df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
        model=trained_a2c, 
        environment = e_trade_gym)
if if_using_td3:
    df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
        model=trained_td3, 
        environment = e_trade_gym)
if if_using_sac:
    df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
        model=trained_sac, 
        environment = e_trade_gym)
# Out:
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# hit end!

# %%
# df_account_value_ppo.shape
# df_account_value_ddpg.shape
# df_account_value_a2c.shape
# df_account_value_td3.shape
# df_account_value_sac.shape

# %%
# df_account_value_ppo.tail()
# df_account_value_ddpg.tail()
# df_account_value_a2c.tail()
# df_account_value_td3.tail()
# df_account_value_sac.tail()

# %%
# df_actions_ppo.head()
# df_actions_ddpg.head()
# df_actions_a2c.head()
# df_actions_td3.head()
# df_actions_sac.head()

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

if if_using_ppo:
  print("\n ppo:")
  perf_stats_all_ppo = backtest_stats(account_value=df_account_value_ppo)
  perf_stats_all_ppo = pd.DataFrame(perf_stats_all_ppo)
  perf_stats_all_ppo.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ppo_"+now+'.csv')

if if_using_ddpg:
  print("\n ddpg:")
  perf_stats_all_ddpg = backtest_stats(account_value=df_account_value_ddpg)
  perf_stats_all_ddpg = pd.DataFrame(perf_stats_all_ddpg)
  perf_stats_all_ddpg.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_ddpg_"+now+'.csv')

if if_using_a2c:
  print("\n a2c:")
  perf_stats_all_a2c = backtest_stats(account_value=df_account_value_a2c)
  perf_stats_all_a2c = pd.DataFrame(perf_stats_all_a2c)
  perf_stats_all_a2c.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_a2c_"+now+'.csv')

if if_using_td3:
  print("\n atd3:")
  perf_stats_all_td3 = backtest_stats(account_value=df_account_value_td3)
  perf_stats_all_td3 = pd.DataFrame(perf_stats_all_td3)
  perf_stats_all_td3.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_td3_"+now+'.csv')

if if_using_sac:
  print("\n sac:")
  perf_stats_all_sac = backtest_stats(account_value=df_account_value_sac)
  perf_stats_all_sac = pd.DataFrame(perf_stats_all_sac)
  perf_stats_all_sac.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_sac_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
#
#  ppo:
# Annual return          0.402409
# Cumulative returns     1.667186
# Annual volatility      0.282249
# Sharpe ratio           1.341558
# Calmar ratio           1.298502
# Stability              0.898956
# Max drawdown          -0.309902
# Omega ratio            1.400417
# Sortino ratio          2.025304
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.257613
# Daily value at risk   -0.034057
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = TEST_START_DATE,
        end = TEST_END_DATE)

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (505, 8)
# Annual return          0.144674
# Cumulative returns     0.310981
# Annual volatility      0.274619
# Sharpe ratio           0.631418
# Calmar ratio           0.390102
# Stability              0.116677
# Max drawdown          -0.370862
# Omega ratio            1.149365
# Sortino ratio          0.870084
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.860710
# Daily value at risk   -0.033911
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## BackTestPlotting

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX

if if_using_ppo or if_using_ppo_adv_ppo:
  backtest_plot(df_account_value_ppo, 
              baseline_ticker = '^DJI', 
              baseline_start = TEST_START_DATE,
              baseline_end = TEST_END_DATE)

if if_using_ddpg:
  backtest_plot(df_account_value_ddpg, 
              baseline_ticker = '^DJI', 
              baseline_start = TEST_START_DATE,
              baseline_end = TEST_END_DATE)

if if_using_a2c:
  backtest_plot(df_account_value_a2c, 
              baseline_ticker = '^DJI', 
              baseline_start = TEST_START_DATE,
              baseline_end = TEST_END_DATE)

if if_using_td3:
  backtest_plot(df_account_value_td3, 
              baseline_ticker = '^DJI', 
              baseline_start = TEST_START_DATE,
              baseline_end = TEST_END_DATE)

if if_using_sac:
  print(df_account_value_sac.head())
  print(type(df_account_value_sac))
  backtest_plot(df_account_value_sac, 
              baseline_ticker = '^DJI', 
              baseline_start = TEST_START_DATE,
              baseline_end = TEST_END_DATE)
# Out:
# ==============Compare to DJIA===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (505, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>34</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>40.241%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>166.719%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>28.225%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.34</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.30</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-30.99%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.40</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.03</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.406%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.63</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>30.99</td>
#       <td>2020-02-12</td>
#       <td>2020-03-23</td>
#       <td>2020-06-05</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20.20</td>
#       <td>2020-09-01</td>
#       <td>2020-09-18</td>
#       <td>2020-12-25</td>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7.24</td>
#       <td>2019-05-03</td>
#       <td>2019-06-03</td>
#       <td>2019-07-03</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.91</td>
#       <td>2019-07-31</td>
#       <td>2019-08-05</td>
#       <td>2019-08-21</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.77</td>
#       <td>2020-07-18</td>
#       <td>2020-07-24</td>
#       <td>2020-07-31</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/pyfolio/plotting.py:1304: UserWarning: The palette list has more values (3) than needed (1), which may not be intended.
#   sns.boxplot(data=[is_returns, is_weekly, is_monthly],
# /Users/robertli/miniconda3/envs/FinRL/lib/python3.10/site-packages/pyfolio/plotting.py:1320: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['Daily', 'Weekly', 'Monthly'])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.15%</td>
#       <td>-12.65%</td>
#       <td>11.76%</td>
#     </tr>
#   </tbody>
# </table>
